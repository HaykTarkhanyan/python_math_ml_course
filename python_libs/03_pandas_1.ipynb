# %% [raw]
# ---
# title: "03 Pandas 1"
# lightbox: true
# format:
#   html:
#     code-fold: false
# number-offset: 1
# ---

# %% [markdown]
# ![image.png](../background_photos/libs_03_kond_street_art.jpg)
# Կոնդ, [լուսանկարի հղումը](https://unsplash.com/photos/a-narrow-street-with-graffiti-on-the-walls-LM1PgBVWbm8), Հեղինակ՝ [Tigran Shishmanyan](https://unsplash.com/@tiknycman)

# %% [markdown]
# # 🎦 Տեսադասեր + լրացուցիչ (ToDo)
#
# ToDo
# 1. [Տեսություն 2025](https://youtu.be/TIWU_bjFuUc) \
# 2. [Տեսություն 2023 (ToDo)]()  \
# 3. [Գործնական 2025](https://youtu.be/zf8xEfdLXRo) \
# 4. [Գործնական 2023 (ToDo)]()  \
# 5. [Որոշ տնայինների լուծումներ (ToDo)]()
#
# Google Forms ToDo

# %% [markdown]
# # 📚 Նյութը
# 1. [Docs](https://pandas.pydata.org/docs)
# 2. [Youtube video](https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS)
# 3. [Kaggle mini course](https://www.kaggle.com/learn/pandas)

# %% [markdown]
# <img src='https://img.freepik.com/premium-vector/cute-panda-holding-balloons-cartoon-vector_42750-791.jpg?w=2000' width=500 height=500>

# %% [markdown]
# Pandas(Panel data)-ը Python-ի գրադարան է, աղյուսակային(Tabular) տվյալների հետ աշխատելու համար,
#
# Կարող ենք պատկերացնել իրեն ինչպես Excel-ը ուղղակի ավելի ճկուն
#
# Աղյուսակային տվյալ ասելով հասկանում ենք՝
#
# <img src='https://www.statology.org/wp-content/uploads/2022/03/tabular1.jpg' width=500 hight=500>

# %% [markdown]
# **Մոտիվացիոն խնդիր՝ (կպատասխանենք այստեղից որոշ խնդիրների)**

# %% [markdown]
# 1. Քանի՞ տարեկան է ամենատարեց մարդը (գործողություններ Series-ների հետ)
# 2. Ո՞րն է ամենատարածված անունը (**value_counts**)
# 3. Ի՞նչ է ամենատարեց մարդու անունը (**filtering**)
# 4. Քանի յուրօրինակ անուն կա (**nunique**)
# 6. Անվան միջին երկարությունյան փոփոխությունը ըստ տարվա (**apply**, **groupby**)
# 5. Ամենատարածված անունը ըստ տարվա (**groupby**, )
# 7. Յուրօրինակ անունների քանակը ըստ տարբա (**groupby**, )
# 8. Անվան տարիքը
# 9. Ամենաշատը որ օրը ծնունդ կա
# 10. Ամենաերկար անունը

# %% [markdown]
# ## Pandas գրադարանը

# %%
# !pip install pandas

# կամ conda install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %% [markdown]
# ### Series-ի ստեղծում

# %% [markdown]
# #### List-ի միջոցով

# %%
list_1 = ['a', 'b', 'c']

s = pd.Series(list_1)
print(type(s))
s
# Out:
# <class 'pandas.core.series.Series'>
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
print(type(s.values))
s.values
# Out:
# <class 'numpy.ndarray'>
# array(['a', 'b', 'c'], dtype=object)

# %%
indexes = ['առաջին', 'երկրորդ', 'երրորդ']

s = pd.Series(list_1, index=indexes)
print(s)
# Out:
# առաջին     a
# երկրորդ    b
# երրորդ     c
# dtype: object

# %% [markdown]
# #### Dictionary-ի միջոցով

# %%
d = {'first': 'a',
     'second': 'b',
     'third': 'c'}
s = pd.Series(d)
print(s)
# Out:
# first     a
# second    b
# third     c
# dtype: object

# %% [markdown]
# ### գործողություններ Series-ների հետ

# %%
s1 = pd.Series([3,4,1, 0, 3])

s1
# Out:
# 0    3
# 1    4
# 2    1
# 3    0
# 4    3
# dtype: int64

# %%
s1 + 3 # կամ հանած
# Out:
# 0    6
# 1    7
# 2    4
# 3    3
# 4    6
# dtype: int64

# %%
s1 / 4 # կամ բազմապատկած
# Out:
# 0    0.75
# 1    1.00
# 2    0.25
# 3    0.00
# 4    0.75
# dtype: float64

# %%
s1.sort_values()
# Out:
# 3    0
# 2    1
# 0    3
# 4    3
# 1    4
# dtype: int64

# %%
s1.apply(lambda x: x * 395 / 1000)
# Out:
# 0    1.185
# 1    1.580
# 2    0.395
# 3    0.000
# 4    1.185
# dtype: float64

# %%
print(s1.max())
print(s1.min())
print(s1.mean())
print(s1.mode())
# Out:
# 4
# 0
# 2.2
# 0    3
# dtype: int64

# %%
s1.unique()
# Out:
# array([3, 4, 1, 0])

# %%
s1.nunique()
# Out:
# 4

# %%
s1.value_counts()
# Out:
# 3    2
# 4    1
# 1    1
# 0    1
# Name: count, dtype: int64

# %%
help(s1)

# %%
kurs = pd.Series([395, 435])
qanak = pd.Series([5, 6])

dram = qanak * kurs
print(dram)
print(dram.sum())
# Out:
# 0    1975
# 1    2610
# dtype: int64
# 4585

# %% [markdown]
# Նենց հավես կլիներ էս սաղ մի հատ աղյուսակով լիներ ոչթե տարբեր փոփոխականներում պահեինք

# %%
pd.DataFrame({'Փոխարժեք': kurs, 'Քանակ': qanak, 'Ընդհանուր գումար':dram})

# %% [markdown]
# ## CSV format

# %% [markdown]
# CSV-ն դա Comma seperated values-ի հապավումնա՝ ստորակետով բաժանված արժեքներ, օրինակ՝

# %%
azganun,anun,haeranun,or_amis_tari,marz,hamaenq,bnakavaer,hasce,taracq,texamas
Վարդանյան,Վարդան,Շաքարի,14/11/1798,ԿՈՏԱՅՔ,ՆՈՐ ՀԱՃՆ,,Չարենցի Փ.31 1,28,28/01
Վարդանյան,Ադիկ,Ժորայի,14/03/1444,ԿՈՏԱՅՔ,ՆՈՐ ՀԱՃՆ,,Սևակի Փ. 311,28,28/01

# %% [markdown]
# ## Data Frame

# %%
df = pd.read_csv("assets/elections.csv")
# Out:
# C:\Users\hayk_\AppData\Local\Temp\ipykernel_4696\591096373.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("assets/elections.csv")

# %%
# խառնել տվյալները
df['texamas'] = df['texamas'].sample(frac=1).values
df['haeranun'] = df['haeranun'].sample(frac=1).values
df['hasce'] = df['hasce'].sample(frac=1).values
df['hamaenq'] = df['hamaenq'].sample(frac=1).values

# %%
df
# Out:
#                azganun        anun    haeranun or_amis_tari    marz  \
# 0        Հարությունյան       Կարեն   Վալոդյայի   14/11/1997  ԿՈՏԱՅՔ
# 1            Աղաջանյան      Կարինե       Արամի   14/08/1964  ԿՈՏԱՅՔ
# 2        Հարությունյան  Հարություն   Վարազդատի   29/10/1986  ԿՈՏԱՅՔ
# 3           Ալեքսանյան      Համեստ     Ռուբիկի   24/10/1954  ԿՈՏԱՅՔ
# 4        Հարությունյան       Շաքար  Արիստակեսի   01/01/1959  ԿՈՏԱՅՔ
# ...                ...         ...         ...          ...     ...
# 2577168     Շահվերդյան         Ալա    Անդրուշի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան      Կարինե     Ալբերտի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան      Անահիտ      Արսենի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան      Նարինե     Վարդանի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան      Գայանե   Սերյոժայի   24/04/1966    ԼՈՌԻ
#
#                   hamaenq bnakavaer                          hasce  taracq  \
# 0                    ԲԵՐԴ       NaN                      3 Փ.   31      28
# 1                 ԳՅՈՒՄՐԻ       NaN        Սիլիկյան Թղմ. 1 Փ.   15      28
# 2                  ՍԻՍԻԱՆ       NaN             Ե. Չարենցի Փ.   10      28
# 3                ԳԵՂԱՆԻՍՏ       NaN           Կիեւյան Փ.   11   18      28
# 4                ԱԽՈՒՐՅԱՆ       NaN             Սպանդարյան Փ.   25      28
# ...                   ...       ...                            ...     ...
# 2577168          ԱՋԱՓՆՅԱԿ       NaN                  21 Փ.   6   1      23
# 2577169           ԳՈՒԳԱՐՔ       NaN                      3 Փ.   12      23
# 2577170  ՄԱԼԱԹԻԱ-ՍԵԲԱՍՏԻԱ       NaN         Զվարթնոց Թղմ.   7   36      23
# 2577171          ԴԱՎԹԱՇԵՆ       NaN          Մեքենավարների Փ.   85      23
# 2577172          ԳԵՏԱՓՆՅԱ       NaN  Ն. Շենգավիթ 11 Փ.   1/21   22      23
#
#         texamas
# 0         27/41
# 1         17/62
# 2         19/20
# 3          7/24
# 4          7/26
# ...         ...
# 2577168    5/19
# 2577169   38/07
# 2577170   13/40
# 2577171   18/34
# 2577172   31/23
#
# [2577173 rows x 10 columns]

# %% [markdown]
# ### Գլուխը, պոչը ստանալ

# %%
df.head(2)
# Out:
#          azganun    anun  haeranun or_amis_tari    marz   hamaenq bnakavaer  \
# 0  Հարությունյան   Կարեն   Գրիգորի   14/11/1997  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ       NaN
# 1      Աղաջանյան  Կարինե  Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ   ԱՐՏԻՄԵՏ       NaN
#
#                         hasce  taracq texamas
# 0  Համբարձումյան Փ.   14   33      28   22/22
# 1        Իսակովի Փ.   99   15      28    5/08

# %%
df.tail(6)
# Out:
#             azganun     anun    haeranun or_amis_tari  marz    hamaenq  \
# 2577167    Ասլանյան  Տաթեւիկ      Մասիսի   15/09/1982  ԼՈՌԻ    ԳՅՈՒՄՐԻ
# 2577168  Շահվերդյան      Ալա     Սեդրակի   22/04/1987  ԼՈՌԻ     ՍԻՍԻԱՆ
# 2577169   Իսրաելյան   Կարինե  Անուշավանի   13/03/1960  ԼՈՌԻ  ՇԱՀՈՒՄՅԱՆ
# 2577170   Գրիգորյան   Անահիտ      Լեւոնի   12/05/1970  ԼՈՌԻ     ՍԻՍԻԱՆ
# 2577171    Սահակյան   Նարինե     Ռուբենի   25/09/1978  ԼՈՌԻ   ՇԵՆԳԱՎԻԹ
# 2577172    Մկրտչյան   Գայանե       Էդիկի   24/04/1966  ԼՈՌԻ       ՎԵԴԻ
#
#         bnakavaer                     hasce  taracq texamas
# 2577167       NaN  Տիգրան Մեծի Փ.   31   90      23   11/46
# 2577168       NaN    Շահումյան Փ.   97   46      23   18/69
# 2577169       NaN    Բ. Մարտիրոսյան Փ.   23      23   13/54
# 2577170       NaN      Թումանյան 3 Նրբ.   8      23    6/39
# 2577171       NaN                  9 Փ.   1      23   33/11
# 2577172       NaN   Վիլնյուսի Փ.   115   40      23   32/23

# %% [markdown]
# ### Հստակ ինդեքսների կամ սյուներ ստանալ

# %% [markdown]
# #### Սյուներ

# %%
df['anun'] # նույննա ինչ df.anun բայց այս ձևը նախընտրելի չէ
# Out:
# 0               Կարեն
# 1              Կարինե
# 2          Հարություն
# 3              Համեստ
# 4               Շաքար
#               ...
# 2577168           Ալա
# 2577169        Կարինե
# 2577170        Անահիտ
# 2577171        Նարինե
# 2577172        Գայանե
# Name: anun, Length: 2577173, dtype: object

# %%
print(type(df['anun']))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# **Խոստացած հարցերին սկսենք պատասխանել հազիվ**

# %%
df['anun'].nunique()
# Out:
# 22062

# %%
df['anun'].value_counts()
# Out:
# anun
# Անահիտ       49648
# Արմեն        43860
# Արթուր       40577
# Աննա         37881
# Գայանե       37765
#              ...
# Մարանիկ          1
# Վարդանան         1
# Բազմանուշ        1
# Բերոժ            1
# Լուսետտա         1
# Name: count, Length: 22062, dtype: int64

# %%
df[['anun', 'azganun']]
# Out:
#                anun        azganun
# 0             Կարեն  Հարությունյան
# 1            Կարինե      Աղաջանյան
# 2        Հարություն  Հարությունյան
# 3            Համեստ     Ալեքսանյան
# 4             Շաքար  Հարությունյան
# ...             ...            ...
# 2577168         Ալա     Շահվերդյան
# 2577169      Կարինե      Իսրաելյան
# 2577170      Անահիտ      Գրիգորյան
# 2577171      Նարինե       Սահակյան
# 2577172      Գայանե       Մկրտչյան
#
# [2577173 rows x 2 columns]

# %%
df.head(10)
# Out:
#          azganun        anun    haeranun or_amis_tari    marz     hamaenq  \
# 0  Հարությունյան       Կարեն     Արարատի   14/11/1997  ԿՈՏԱՅՔ        ԱՎԱՆ
# 1      Աղաջանյան      Կարինե    Ալեքսանի   14/08/1964  ԿՈՏԱՅՔ    ԱՋԱՓՆՅԱԿ
# 2  Հարությունյան  Հարություն      Միսակի   29/10/1986  ԿՈՏԱՅՔ     ԶՈԼԱՔԱՐ
# 3     Ալեքսանյան      Համեստ  Հովհաննեսի   24/10/1954  ԿՈՏԱՅՔ     ԱՐԱԲԿԻՐ
# 4  Հարությունյան       Շաքար     Հովսեփի   01/01/1959  ԿՈՏԱՅՔ    ՆՈՐ ՆՈՐՔ
# 5       Լազարյան       Հակոբ   Արտավազդի   25/07/1977  ԿՈՏԱՅՔ       ԳԵՏԱՓ
# 6        Վերդյան    Շուշանիկ     Սամվելի   05/10/1951  ԿՈՏԱՅՔ  ՉԱՐԵՆՑԱՎԱՆ
# 7      Գեւորգյան      Միլենա    Կարապետի   04/09/1987  ԿՈՏԱՅՔ  ՄՅԱՍՆԻԿՅԱՆ
# 8      Մուրադյան   Արմենուհի     Մանուկի   23/05/1982  ԿՈՏԱՅՔ         ՍԻՍ
# 9      Մուրադյան       Արտակ      Աղվանի   27/05/1973  ԿՈՏԱՅՔ        ԱՎԱՆ
#
#   bnakavaer                    hasce  taracq texamas
# 0       NaN    Պատկանյան Փ.   43   2      28   10/09
# 1       NaN         Խորենացու Փ.   8      28   25/17
# 2       NaN                 6 Փ.   6      28    2/06
# 3       NaN      Սունդուկյան Փ.   18      28    7/14
# 4       NaN               10 Փ.   17      28    8/26
# 5       NaN  Չուխաջյան Թղմ.   28   1      28   13/22
# 6       NaN   Օգանովի Փ.   46/1   10      28   18/57
# 7       NaN     Կենտրոն   91   76-77      28   10/29
# 8       NaN        3 Փ.   8 Բնակարան      28   27/31
# 9       NaN                 6 Փ.   5      28   23/23

# %% [markdown]
# #### Տողեր

# %%
df.iloc[0]
# Out:
# azganun                      Հարությունյան
# anun                                 Կարեն
# haeranun                           Գրիգորի
# or_amis_tari                    14/11/1997
# marz                                ԿՈՏԱՅՔ
# hamaenq                           ՇԵՆԳԱՎԻԹ
# bnakavaer                              NaN
# hasce           Համբարձումյան Փ.   14   33
# taracq                                  28
# texamas                              22/22
# Name: 0, dtype: object

# %%
df.iloc[1:7:2]
# Out:
#       azganun    anun  haeranun or_amis_tari    marz           hamaenq  \
# 1   Աղաջանյան  Կարինե  Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ           ԱՐՏԻՄԵՏ
# 3  Ալեքսանյան  Համեստ    Շամիրի   24/10/1954  ԿՈՏԱՅՔ           ՌԱՆՉՊԱՐ
# 5    Լազարյան   Հակոբ    Միշայի   25/07/1977  ԿՈՏԱՅՔ  ՄԱԼԱԹԻԱ-ՍԵԲԱՍՏԻԱ
#
#   bnakavaer                     hasce  taracq texamas
# 1       NaN      Իսակովի Փ.   99   15      28    5/08
# 3       NaN      Գուսան Աշոտի Փ.   11      28   32/38
# 5       NaN  Ա. Խաչատրյան Փ.   15   9      28    3/24

# %%
df_ = df.set_index("anun")
df_
# Out:
#                   azganun    haeranun or_amis_tari    marz    hamaenq  \
# anun
# Կարեն       Հարությունյան     Գրիգորի   14/11/1997  ԿՈՏԱՅՔ   ՇԵՆԳԱՎԻԹ
# Կարինե          Աղաջանյան    Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ    ԱՐՏԻՄԵՏ
# Հարություն  Հարությունյան       Աշոտի   29/10/1986  ԿՈՏԱՅՔ     ԻՋԵՎԱՆ
# Համեստ         Ալեքսանյան      Շամիրի   24/10/1954  ԿՈՏԱՅՔ    ՌԱՆՉՊԱՐ
# Շաքար       Հարությունյան       Արամի   01/01/1959  ԿՈՏԱՅՔ    ԱԲՈՎՅԱՆ
# ...                   ...         ...          ...     ...        ...
# Ալա            Շահվերդյան     Սեդրակի   22/04/1987    ԼՈՌԻ     ՍԻՍԻԱՆ
# Կարինե          Իսրաելյան  Անուշավանի   13/03/1960    ԼՈՌԻ  ՇԱՀՈՒՄՅԱՆ
# Անահիտ          Գրիգորյան      Լեւոնի   12/05/1970    ԼՈՌԻ     ՍԻՍԻԱՆ
# Նարինե           Սահակյան     Ռուբենի   25/09/1978    ԼՈՌԻ   ՇԵՆԳԱՎԻԹ
# Գայանե           Մկրտչյան       Էդիկի   24/04/1966    ԼՈՌԻ       ՎԵԴԻ
#
#            bnakavaer                       hasce  taracq texamas
# anun
# Կարեն            NaN  Համբարձումյան Փ.   14   33      28   22/22
# Կարինե           NaN        Իսակովի Փ.   99   15      28    5/08
# Հարություն       NaN          Չեխովի Փ.   34   3      28   14/03
# Համեստ           NaN        Գուսան Աշոտի Փ.   11      28   32/38
# Շաքար            NaN        Պռոշյան Փ.   10   27      28   13/15
# ...              ...                         ...     ...     ...
# Ալա              NaN      Շահումյան Փ.   97   46      23   18/69
# Կարինե           NaN      Բ. Մարտիրոսյան Փ.   23      23   13/54
# Անահիտ           NaN        Թումանյան 3 Նրբ.   8      23    6/39
# Նարինե           NaN                    9 Փ.   1      23   33/11
# Գայանե           NaN     Վիլնյուսի Փ.   115   40      23   32/23
#
# [2577173 rows x 9 columns]

# %%
df_.iloc[0]
# Out:
# azganun                    Հարությունյան
# haeranun                         Գեւորգի
# or_amis_tari                  14/11/1997
# marz                              ԿՈՏԱՅՔ
# hamaenq                         ՆՈՐ ՆՈՐՔ
# bnakavaer                            NaN
# hasce           Արցախի 4 Նրբ.   10   418
# taracq                                28
# texamas                            13/25
# Name: Կարեն, dtype: object

# %%
df_.loc["Հայկ"]
# Out:
#            azganun   haeranun or_amis_tari    marz           hamaenq  \
# anun
# Հայկ      Ղազարյան     Արտակի   28/03/1992  ԿՈՏԱՅՔ             ԱՐԵՆԻ
# Հայկ      Ղազարյան     Արշակի   28/07/1996  ԿՈՏԱՅՔ    ՆԵՐՔԻՆ ԳԵՏԱՇԵՆ
# Հայկ  Ղավալբաբունց     Սայաթի   26/10/1981  ԿՈՏԱՅՔ              ՎԱՅՔ
# Հայկ    Մաթեւոսյան    Ստեփանի   22/10/1998  ԿՈՏԱՅՔ           ԳՅՈՒՄՐԻ
# Հայկ    Մաթեւոսյան     Ռոմիկի   09/08/1949  ԿՈՏԱՅՔ  ՄԱԼԱԹԻԱ-ՍԵԲԱՍՏԻԱ
# ...            ...        ...          ...     ...               ...
# Հայկ   Բաղդասարյան    Արտուշի   01/07/1998    ԼՈՌԻ          ՆՈՐ ՆՈՐՔ
# Հայկ      Գագինյան     Գագիկի   23/03/1987    ԼՈՌԻ        ՉԱՐԵՆՑԱՎԱՆ
# Հայկ     Գրիգորյան     Սիմոնի   20/12/1972    ԼՈՌԻ           ԱՐՏԱՇԱՏ
# Հայկ      Աֆրիկյան  Վոլոդյայի   28/02/1993    ԼՈՌԻ        ՄԵԾ ՄԱՆԹԱՇ
# Հայկ       Խամոյան     Նորիկի   02/11/1988    ԼՈՌԻ           ԴԻԼԻՋԱՆ
#
#      bnakavaer                           hasce  taracq texamas
# anun
# Հայկ       NaN                3 Փ. 1 Փկղ.   10      28    9/38
# Հայկ       NaN                         Ժնթ   1      28   15/42
# Հայկ       NaN                       1 Փ.   51      28   36/05
# Հայկ       NaN                      8 Փ.   269      28   34/01
# Հայկ       NaN                   Ծավ 2 Փ.   12      28   26/26
# ...        ...                             ...     ...     ...
# Հայկ       NaN             Աթարբեկյան Փ.   103      23   15/21
# Հայկ       NaN            Այգեստան 11 Փ.   115      23    3/14
# Հայկ       NaN  Քանաքեռ Հէկ Բանավան   2/2   21      23   20/30
# Հայկ       NaN    Ազատամարտիկների Փ.   1   224      23   22/37
# Հայկ       NaN                Նար-Դոսի Փ.   1Ա      23   21/36
#
# [18739 rows x 9 columns]

# %% [markdown]
# ### Ըստ սյան և տողի

# %%
df.values

# %%
df.iloc[0,2]
# Out:
# 'Գրիգորի'

# %%
df.values[0,2]
# Out:
# 'Գեւորգի'

# %%
df.iloc[1:3, 2:4]
# Out:
#    haeranun or_amis_tari
# 1  Մամիկոնի   14/08/1964
# 2     Աշոտի   29/10/1986

# %%
df.loc[1, 'hamaenq']
# Out:
# 'ԱՐՏԻՄԵՏ'

# %% [markdown]
# #### Տողի / սյան հեռացում

# %% [markdown]
# <img src='https://i.stack.imgur.com/dcoE3.jpg'>

# %%
df.drop([1, 2, 3], axis=0)
# Out:
#                azganun      anun     haeranun or_amis_tari    marz  \
# 0        Հարությունյան     Կարեն      Գրիգորի   14/11/1997  ԿՈՏԱՅՔ
# 4        Հարությունյան     Շաքար        Արամի   01/01/1959  ԿՈՏԱՅՔ
# 5             Լազարյան     Հակոբ       Միշայի   25/07/1977  ԿՈՏԱՅՔ
# 6              Վերդյան  Շուշանիկ       Ժորայի   05/10/1951  ԿՈՏԱՅՔ
# 7            Գեւորգյան    Միլենա  Հարությունի   04/09/1987  ԿՈՏԱՅՔ
# ...                ...       ...          ...          ...     ...
# 2577168     Շահվերդյան       Ալա      Սեդրակի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան    Կարինե   Անուշավանի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան    Անահիտ       Լեւոնի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան    Նարինե      Ռուբենի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան    Գայանե        Էդիկի   24/04/1966    ԼՈՌԻ
#
#                   hamaenq bnakavaer                       hasce  taracq  \
# 0                ՇԵՆԳԱՎԻԹ       NaN  Համբարձումյան Փ.   14   33      28
# 4                 ԱԲՈՎՅԱՆ       NaN        Պռոշյան Փ.   10   27      28
# 5        ՄԱԼԱԹԻԱ-ՍԵԲԱՍՏԻԱ       NaN    Ա. Խաչատրյան Փ.   15   9      28
# 6                 ՓԱՐԱՔԱՐ       NaN       Երեւանյան Փ.   1   12      28
# 7                 ԱԲՈՎՅԱՆ       NaN   Նոր Նորք 7 Զնգվ.   19   6      28
# ...                   ...       ...                         ...     ...
# 2577168            ՍԻՍԻԱՆ       NaN      Շահումյան Փ.   97   46      23
# 2577169         ՇԱՀՈՒՄՅԱՆ       NaN      Բ. Մարտիրոսյան Փ.   23      23
# 2577170            ՍԻՍԻԱՆ       NaN        Թումանյան 3 Նրբ.   8      23
# 2577171          ՇԵՆԳԱՎԻԹ       NaN                    9 Փ.   1      23
# 2577172              ՎԵԴԻ       NaN     Վիլնյուսի Փ.   115   40      23
#
#         texamas
# 0         22/22
# 4         13/15
# 5          3/24
# 6          3/11
# 7          7/25
# ...         ...
# 2577168   18/69
# 2577169   13/54
# 2577170    6/39
# 2577171   33/11
# 2577172   32/23
#
# [2577170 rows x 10 columns]

# %%
df.drop(['anun', 'azganun'], axis=1)
# Out:
#            haeranun or_amis_tari    marz    hamaenq bnakavaer  \
# 0           Գրիգորի   14/11/1997  ԿՈՏԱՅՔ   ՇԵՆԳԱՎԻԹ       NaN
# 1          Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ    ԱՐՏԻՄԵՏ       NaN
# 2             Աշոտի   29/10/1986  ԿՈՏԱՅՔ     ԻՋԵՎԱՆ       NaN
# 3            Շամիրի   24/10/1954  ԿՈՏԱՅՔ    ՌԱՆՉՊԱՐ       NaN
# 4             Արամի   01/01/1959  ԿՈՏԱՅՔ    ԱԲՈՎՅԱՆ       NaN
# ...             ...          ...     ...        ...       ...
# 2577168     Սեդրակի   22/04/1987    ԼՈՌԻ     ՍԻՍԻԱՆ       NaN
# 2577169  Անուշավանի   13/03/1960    ԼՈՌԻ  ՇԱՀՈՒՄՅԱՆ       NaN
# 2577170      Լեւոնի   12/05/1970    ԼՈՌԻ     ՍԻՍԻԱՆ       NaN
# 2577171     Ռուբենի   25/09/1978    ԼՈՌԻ   ՇԵՆԳԱՎԻԹ       NaN
# 2577172       Էդիկի   24/04/1966    ԼՈՌԻ       ՎԵԴԻ       NaN
#
#                               hasce  taracq texamas
# 0        Համբարձումյան Փ.   14   33      28   22/22
# 1              Իսակովի Փ.   99   15      28    5/08
# 2                Չեխովի Փ.   34   3      28   14/03
# 3              Գուսան Աշոտի Փ.   11      28   32/38
# 4              Պռոշյան Փ.   10   27      28   13/15
# ...                             ...     ...     ...
# 2577168      Շահումյան Փ.   97   46      23   18/69
# 2577169      Բ. Մարտիրոսյան Փ.   23      23   13/54
# 2577170        Թումանյան 3 Նրբ.   8      23    6/39
# 2577171                    9 Փ.   1      23   33/11
# 2577172     Վիլնյուսի Փ.   115   40      23   32/23
#
# [2577173 rows x 8 columns]

# %%
df.drop(columns=["azganun"])
# Out:
#                anun    haeranun or_amis_tari    marz    hamaenq bnakavaer  \
# 0             Կարեն     Գրիգորի   14/11/1997  ԿՈՏԱՅՔ   ՇԵՆԳԱՎԻԹ       NaN
# 1            Կարինե    Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ    ԱՐՏԻՄԵՏ       NaN
# 2        Հարություն       Աշոտի   29/10/1986  ԿՈՏԱՅՔ     ԻՋԵՎԱՆ       NaN
# 3            Համեստ      Շամիրի   24/10/1954  ԿՈՏԱՅՔ    ՌԱՆՉՊԱՐ       NaN
# 4             Շաքար       Արամի   01/01/1959  ԿՈՏԱՅՔ    ԱԲՈՎՅԱՆ       NaN
# ...             ...         ...          ...     ...        ...       ...
# 2577168         Ալա     Սեդրակի   22/04/1987    ԼՈՌԻ     ՍԻՍԻԱՆ       NaN
# 2577169      Կարինե  Անուշավանի   13/03/1960    ԼՈՌԻ  ՇԱՀՈՒՄՅԱՆ       NaN
# 2577170      Անահիտ      Լեւոնի   12/05/1970    ԼՈՌԻ     ՍԻՍԻԱՆ       NaN
# 2577171      Նարինե     Ռուբենի   25/09/1978    ԼՈՌԻ   ՇԵՆԳԱՎԻԹ       NaN
# 2577172      Գայանե       Էդիկի   24/04/1966    ԼՈՌԻ       ՎԵԴԻ       NaN
#
#                               hasce  taracq texamas
# 0        Համբարձումյան Փ.   14   33      28   22/22
# 1              Իսակովի Փ.   99   15      28    5/08
# 2                Չեխովի Փ.   34   3      28   14/03
# 3              Գուսան Աշոտի Փ.   11      28   32/38
# 4              Պռոշյան Փ.   10   27      28   13/15
# ...                             ...     ...     ...
# 2577168      Շահումյան Փ.   97   46      23   18/69
# 2577169      Բ. Մարտիրոսյան Փ.   23      23   13/54
# 2577170        Թումանյան 3 Նրբ.   8      23    6/39
# 2577171                    9 Փ.   1      23   33/11
# 2577172     Վիլնյուսի Փ.   115   40      23   32/23
#
# [2577173 rows x 9 columns]

# %% [markdown]
# բայց կտեսնենք որ դեռ տողը/սյունը ջնջված չէ, քանի որ երբ կիրառեցինք `drop` ֆունկցիան այն մեզ վերադարձրեց df-ն մեջից հեռացնելով մեր ուզածը բայց հենց df ն չփոխեց,
#
# եթե ուզում ենք փոխենք պետք է անենք՝

# %%
df
# Out:
#                azganun        anun   haeranun or_amis_tari    marz   hamaenq  \
# 0        Հարությունյան       Կարեն    Գեւորգի   14/11/1997  ԿՈՏԱՅՔ  ՆՈՐ ՆՈՐՔ
# 1            Աղաջանյան      Կարինե    Մխիթարի   14/08/1964  ԿՈՏԱՅՔ   ՎԱՆԱՁՈՐ
# 2        Հարությունյան  Հարություն     Սենիկի   29/10/1986  ԿՈՏԱՅՔ  ԳԱՆՁԱՔԱՐ
# 3           Ալեքսանյան      Համեստ   Իվանովնա   24/10/1954  ԿՈՏԱՅՔ   ՎԱՆԱՁՈՐ
# 4        Հարությունյան       Շաքար   Ռաֆայելի   01/01/1959  ԿՈՏԱՅՔ     ԳՈՐԻՍ
# ...                ...         ...        ...          ...     ...       ...
# 2577168     Շահվերդյան         Ալա   Շալիկոյի   22/04/1987    ԼՈՌԻ     ՍԵՎԱՆ
# 2577169      Իսրաելյան      Կարինե     Պողոսի   13/03/1960    ԼՈՌԻ   ԳԵՏԱՄԵՋ
# 2577170      Գրիգորյան      Անահիտ  Վլադիմիրի   12/05/1970    ԼՈՌԻ    ՋՐԱՌԱՏ
# 2577171       Սահակյան      Նարինե    Մանուկի   25/09/1978    ԼՈՌԻ    ԼՃԱՎԱՆ
# 2577172       Մկրտչյան      Գայանե     Սադայի   24/04/1966    ԼՈՌԻ     ՏԱՇԻՐ
#
#         bnakavaer                     hasce  taracq texamas
# 0             NaN  Արցախի 4 Նրբ.   10   418      28   13/25
# 1             NaN      Նանսենի Փ.   19   92      28    3/06
# 2             NaN            Աբովյան Փ.   5      28   28/27
# 3             NaN    Կոմիտասի Պ.   55   15Ա      28   11/34
# 4             NaN        Բաղյան Փ.   1   40      28   37/01
# ...           ...                       ...     ...     ...
# 2577168       NaN                  6 Փ.   2      23    6/15
# 2577169       NaN         Սարիթաղ 2 Փ.   24      23    8/58
# 2577170       NaN          12 Փ. 1 Նրբ.   8      23    9/35
# 2577171       NaN        3 Փ. 1 Անցղ.   1/1      23    7/16
# 2577172       NaN                 2 Փ.   15      23    1/15
#
# [2577173 rows x 10 columns]

# %%
help(df.drop)

# %%
# df = df.drop('anun', axis=1)

# կամ

df.drop('anun', axis=1, inplace=True)
# Out:
#            haeranun or_amis_tari    marz           hamaenq bnakavaer  \
# 0            Հակոբի   14/11/1997  ԿՈՏԱՅՔ        ՉԱՐԵՆՑԱՎԱՆ       NaN
# 1          Արտաշեսի   14/08/1964  ԿՈՏԱՅՔ          ՇԵՆԳԱՎԻԹ       NaN
# 2        Անուշավանի   29/10/1986  ԿՈՏԱՅՔ  ՄԱԼԱԹԻԱ-ՍԵԲԱՍՏԻԱ       NaN
# 3            Ցոլակի   24/10/1954  ԿՈՏԱՅՔ          ՇԵՆԳԱՎԻԹ       NaN
# 4           Արտուշի   01/01/1959  ԿՈՏԱՅՔ           ԳԵՏԱՇԵՆ       NaN
# ...             ...          ...     ...               ...       ...
# 2577168   Խաչատուրի   22/04/1987    ԼՈՌԻ        ՆՈՐՔ-ՄԱՐԱՇ       NaN
# 2577169   Վոլոդյայի   13/03/1960    ԼՈՌԻ        ՍՏԵՓԱՆԱՎԱՆ       NaN
# 2577170     Արարատի   12/05/1970    ԼՈՌԻ           ՀՐԱԶԴԱՆ       NaN
# 2577171      Արտակի   25/09/1978    ԼՈՌԻ             ՏԱԹԵՎ       NaN
# 2577172      Վահանի   24/04/1966    ԼՈՌԻ           ԱՐՄԱՎԻՐ       NaN
#
#                                   hasce  taracq texamas
# 0                Ղանդիլյան Փ.   77Ա   1      28   18/39
# 1                      Ղուկասյան Փ.   7      28   38/41
# 2                       5 Փ. 2 Նրբ.   5      28   11/03
# 3                            12 Փ.   19      28   12/43
# 4                  Թումանյան Փ.   2   5      28   24/48
# ...                                 ...     ...     ...
# 2577168  Նոր Խարբերդ Ա/գ 17 Փ.   101/13      23    8/27
# 2577169                1ա Թղմ.   2   24      23    3/15
# 2577170                  Կիրովի Փ.   53      23   34/23
# 2577171                       2 Փ.   27      23    4/03
# 2577172       Նուբարաշեն 11 Փ.   12   1      23   23/57
#
# [2577173 rows x 8 columns]

# %% [markdown]
# #### նոր սյան ստեղծում

# %%
pstik_df = df.head()[['azganun', 'anun']]
pstik_df
# Out:
#          azganun        anun
# 0  Հարությունյան       Կարեն
# 1      Աղաջանյան      Կարինե
# 2  Հարությունյան  Հարություն
# 3     Ալեքսանյան      Համեստ
# 4  Հարությունյան       Շաքար

# %%
pstik_df['sirac tiv'] = [1,2,3,4,5]
pstik_df
# Out:
#          azganun        anun  sirac tiv
# 0  Հարությունյան       Կարեն          1
# 1      Աղաջանյան      Կարինե          2
# 2  Հարությունյան  Հարություն          3
# 3     Ալեքսանյան      Համեստ          4
# 4  Հարությունյան       Շաքար          5

# %%
pstik_df['anun azganun'] = pstik_df['anun'] + " " + pstik_df['azganun']
pstik_df
# Out:
#          azganun        anun  sirac tiv              anun azganun
# 0  Հարությունյան       Կարեն          1       Կարեն Հարությունյան
# 1      Աղաջանյան      Կարինե          2          Կարինե Աղաջանյան
# 2  Հարությունյան  Հարություն          3  Հարություն Հարությունյան
# 3     Ալեքսանյան      Համեստ          4         Համեստ Ալեքսանյան
# 4  Հարությունյան       Շաքար          5       Շաքար Հարությունյան

# %%
# Out:
# 0          1997
# 1          1964
# 2          1986
# 3          1954
# 4          1959
#            ...
# 2577168    1987
# 2577169    1960
# 2577170    1970
# 2577171    1978
# 2577172    1966
# Name: tari, Length: 2577173, dtype: int64

# %%
# Out:
#                azganun        anun   haeranun or_amis_tari    marz  \
# 0        Հարությունյան       Կարեն    Մկրտիչի   14/11/1997  ԿՈՏԱՅՔ
# 1            Աղաջանյան      Կարինե  Նարինբեկի   14/08/1964  ԿՈՏԱՅՔ
# 2        Հարությունյան  Հարություն    Սամվելի   29/10/1986  ԿՈՏԱՅՔ
# 3           Ալեքսանյան      Համեստ   Պավլուշի   24/10/1954  ԿՈՏԱՅՔ
# 4        Հարությունյան       Շաքար     Վանիկի   01/01/1959  ԿՈՏԱՅՔ
# ...                ...         ...        ...          ...     ...
# 2577168     Շահվերդյան         Ալա   Սանասարի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան      Կարինե    Ստեփանի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան      Անահիտ   Միխայելի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան      Նարինե    Սուրենի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան      Գայանե     Սոսինի   24/04/1966    ԼՈՌԻ
#
#             hamaenq bnakavaer                       hasce  taracq texamas  \
# 0            ՆԻԶԱՄԻ       NaN     Շիրվանզադեի Փ.   5   30      28   25/08
# 1        ՍՏԵՓԱՆԱՎԱՆ       NaN    Շերամի 2 Թղմ.   1-3   82      28   14/47
# 2           ԿԵՆՏՐՈՆ       NaN  Նոր Նորք 8 Զնգվ.   33   22      28   21/27
# 3        ՎԱՂԱՐՇԱՊԱՏ       NaN  Հաղթանակ 2 Փ. 1 Նրբ.   1/3      28   35/20
# 4             ԿԱՊԱՆ       NaN      Հ/Ա բ2 Թղմ.   139   10      28    8/36
# ...             ...       ...                         ...     ...     ...
# 2577168      ԱԽԹԱԼԱ       NaN         1 Փ. 1 Նրբ.   9   3      23   22/05
# 2577169     ՍԱՐԱՄԵՋ       NaN         Մաշտոցի Փ.   1   40      23   23/44
# 2577170     ՎԱՆԱՁՈՐ       NaN      Շահումյան Փ.   59   13      23   12/12
# 2577171     ԳՅՈՒՄՐԻ       NaN                5 Փ.   194/1      23   23/31
# 2577172     ՋԱՆՖԻԴԱ       NaN      Վիլնյուսի Փ.   85   67      23   19/28
#
#          tari  tariq
# 0        1997     26
# 1        1964     59
# 2        1986     37
# 3        1954     69
# 4        1959     64
# ...       ...    ...
# 2577168  1987     36
# 2577169  1960     63
# 2577170  1970     53
# 2577171  1978     45
# 2577172  1966     57
#
# [2577173 rows x 12 columns]

# %% [markdown]
# #### Նոր տողի ավելացում

# %%
pstik_df
# Out:
#          azganun        anun  sirac tiv              anun azganun
# 0  Հարությունյան       Կարեն          1       Կարեն Հարությունյան
# 1      Աղաջանյան      Կարինե          2          Կարինե Աղաջանյան
# 2  Հարությունյան  Հարություն          3  Հարություն Հարությունյան
# 3     Ալեքսանյան      Համեստ          4         Համեստ Ալեքսանյան
# 4  Հարությունյան       Շաքար          5       Շաքար Հարությունյան

# %%
nor_mard = pd.Series({'anun': 'Անուն', "azganun": "Ազգանունյան",
                     "sirac tiv": 509, 'anun azganun': "Անուն Ազգանունյան"}, name='մարդուկ')

pstik_df = pd.concat((pstik_df, nor_mard))
pstik_df
# nor_mard
# Out:
#                     azganun        anun  sirac tiv              anun azganun  \
# 0             Հարությունյան       Կարեն        1.0       Կարեն Հարությունյան
# 1                 Աղաջանյան      Կարինե        2.0          Կարինե Աղաջանյան
# 2             Հարությունյան  Հարություն        3.0  Հարություն Հարությունյան
# 3                Ալեքսանյան      Համեստ        4.0         Համեստ Ալեքսանյան
# 4             Հարությունյան       Շաքար        5.0       Շաքար Հարությունյան
# anun                    NaN         NaN        NaN                       NaN
# azganun                 NaN         NaN        NaN                       NaN
# sirac tiv               NaN         NaN        NaN                       NaN
# anun azganun            NaN         NaN        NaN                       NaN
#
#                         մարդուկ
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# anun                      Անուն
# azganun             Ազգանունյան
# sirac tiv                   509
# anun azganun  Անուն Ազգանունյան

# %%
pstik_df.loc['մարդուկ']

# pstik_df.index
# Out:
# Index([0, 1, 2, 3, 4, 'մարդուկ'], dtype='object')

# %% [markdown]
# #### Ընդհանուր data frame-ի նկարագիրը ստանալ

# %%
df.shape
# Out:
# (2577173, 10)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2577173, step=1)

# %%
df.columns
# Out:
# Index(['azganun', 'anun', 'haeranun', 'or_amis_tari', 'marz', 'hamaenq',
#        'bnakavaer', 'hasce', 'taracq', 'texamas'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577173 entries, 0 to 2577172
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   azganun       object
#  1   anun          object
#  2   haeranun      object
#  3   or_amis_tari  object
#  4   marz          object
#  5   hamaenq       object
#  6   bnakavaer     object
#  7   hasce         object
#  8   taracq        int64
#  9   texamas       object
# dtypes: int64(1), object(9)
# memory usage: 196.6+ MB

# %%
df.describe()
# Out:
#              taracq
# count  2.577173e+06
# mean   1.775785e+01
# std    1.072279e+01
# min    1.000000e+00
# 25%    8.000000e+00
# 50%    1.600000e+01
# 75%    2.700000e+01
# max    3.800000e+01

# %% [markdown]
# ## Տվյալների ֆիլտրում

# %% [markdown]
# ### Մի պայման

# %%
pstik_df = df.head(5)
pstik_df
# Out:
#          azganun        anun  haeranun or_amis_tari    marz   hamaenq  \
# 0  Հարությունյան       Կարեն   Գրիգորի   14/11/1997  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ
# 1      Աղաջանյան      Կարինե  Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ   ԱՐՏԻՄԵՏ
# 2  Հարությունյան  Հարություն     Աշոտի   29/10/1986  ԿՈՏԱՅՔ    ԻՋԵՎԱՆ
# 3     Ալեքսանյան      Համեստ    Շամիրի   24/10/1954  ԿՈՏԱՅՔ   ՌԱՆՉՊԱՐ
# 4  Հարությունյան       Շաքար     Արամի   01/01/1959  ԿՈՏԱՅՔ   ԱԲՈՎՅԱՆ
#
#   bnakavaer                       hasce  taracq texamas
# 0       NaN  Համբարձումյան Փ.   14   33      28   22/22
# 1       NaN        Իսակովի Փ.   99   15      28    5/08
# 2       NaN          Չեխովի Փ.   34   3      28   14/03
# 3       NaN        Գուսան Աշոտի Փ.   11      28   32/38
# 4       NaN        Պռոշյան Փ.   10   27      28   13/15

# %%
pstik_df['azganun'] == 'Հարությունյան'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: azganun, dtype: bool

# %%
pstik_df[pstik_df['azganun'] == 'Հարությունյան']
# Out:
#          azganun        anun haeranun or_amis_tari    marz   hamaenq  \
# 0  Հարությունյան       Կարեն  Գրիգորի   14/11/1997  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ
# 2  Հարությունյան  Հարություն    Աշոտի   29/10/1986  ԿՈՏԱՅՔ    ԻՋԵՎԱՆ
# 4  Հարությունյան       Շաքար    Արամի   01/01/1959  ԿՈՏԱՅՔ   ԱԲՈՎՅԱՆ
#
#   bnakavaer                       hasce  taracq texamas
# 0       NaN  Համբարձումյան Փ.   14   33      28   22/22
# 2       NaN          Չեխովի Փ.   34   3      28   14/03
# 4       NaN        Պռոշյան Փ.   10   27      28   13/15

# %% [markdown]
# ### մի քանի պայման

# %%
(pstik_df['azganun'] == 'Հարությունյան') & (pstik_df['anun'] == 'Կարեն')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
pstik_df[(pstik_df['azganun'] == 'Հարությունյան') & (pstik_df['anun'] == 'Կարեն') ]
# Out:
#          azganun   anun haeranun or_amis_tari    marz   hamaenq bnakavaer  \
# 0  Հարությունյան  Կարեն  Գրիգորի   14/11/1997  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ       NaN
#
#                         hasce  taracq texamas
# 0  Համբարձումյան Փ.   14   33      28   22/22

# %%
pstik_df[(pstik_df['azganun'] == 'Հարությունյան') | (pstik_df['anun'] == 'Կարեն') ]
# Out:
#          azganun        anun haeranun or_amis_tari    marz   hamaenq  \
# 0  Հարությունյան       Կարեն  Գրիգորի   14/11/1997  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ
# 2  Հարությունյան  Հարություն    Աշոտի   29/10/1986  ԿՈՏԱՅՔ    ԻՋԵՎԱՆ
# 4  Հարությունյան       Շաքար    Արամի   01/01/1959  ԿՈՏԱՅՔ   ԱԲՈՎՅԱՆ
#
#   bnakavaer                       hasce  taracq texamas
# 0       NaN  Համբարձումյան Փ.   14   33      28   22/22
# 2       NaN          Չեխովի Փ.   34   3      28   14/03
# 4       NaN        Պռոշյան Փ.   10   27      28   13/15

# %% [markdown]
# ### Օրինակ

# %% [markdown]
# Քանի տարեկան է իքս անունով ամենածեր մարդը

# %%
df
# Out:
#                azganun        anun   haeranun or_amis_tari    marz   hamaenq  \
# 0        Հարությունյան       Կարեն    Գեւորգի   14/11/1997  ԿՈՏԱՅՔ  ՆՈՐ ՆՈՐՔ
# 1            Աղաջանյան      Կարինե    Մխիթարի   14/08/1964  ԿՈՏԱՅՔ   ՎԱՆԱՁՈՐ
# 2        Հարությունյան  Հարություն     Սենիկի   29/10/1986  ԿՈՏԱՅՔ  ԳԱՆՁԱՔԱՐ
# 3           Ալեքսանյան      Համեստ   Իվանովնա   24/10/1954  ԿՈՏԱՅՔ   ՎԱՆԱՁՈՐ
# 4        Հարությունյան       Շաքար   Ռաֆայելի   01/01/1959  ԿՈՏԱՅՔ     ԳՈՐԻՍ
# ...                ...         ...        ...          ...     ...       ...
# 2577168     Շահվերդյան         Ալա   Շալիկոյի   22/04/1987    ԼՈՌԻ     ՍԵՎԱՆ
# 2577169      Իսրաելյան      Կարինե     Պողոսի   13/03/1960    ԼՈՌԻ   ԳԵՏԱՄԵՋ
# 2577170      Գրիգորյան      Անահիտ  Վլադիմիրի   12/05/1970    ԼՈՌԻ    ՋՐԱՌԱՏ
# 2577171       Սահակյան      Նարինե    Մանուկի   25/09/1978    ԼՈՌԻ    ԼՃԱՎԱՆ
# 2577172       Մկրտչյան      Գայանե     Սադայի   24/04/1966    ԼՈՌԻ     ՏԱՇԻՐ
#
#         bnakavaer                     hasce  taracq texamas
# 0             NaN  Արցախի 4 Նրբ.   10   418      28   13/25
# 1             NaN      Նանսենի Փ.   19   92      28    3/06
# 2             NaN            Աբովյան Փ.   5      28   28/27
# 3             NaN    Կոմիտասի Պ.   55   15Ա      28   11/34
# 4             NaN        Բաղյան Փ.   1   40      28   37/01
# ...           ...                       ...     ...     ...
# 2577168       NaN                  6 Փ.   2      23    6/15
# 2577169       NaN         Սարիթաղ 2 Փ.   24      23    8/58
# 2577170       NaN          12 Փ. 1 Նրբ.   8      23    9/35
# 2577171       NaN        3 Փ. 1 Անցղ.   1/1      23    7/16
# 2577172       NaN                 2 Փ.   15      23    1/15
#
# [2577173 rows x 10 columns]

# %%
df['tari'] = df['or_amis_tari'].apply(lambda x: int(x[-4:]))
df['tari']
# Out:
# 0          1997
# 1          1964
# 2          1986
# 3          1954
# 4          1959
#            ...
# 2577168    1987
# 2577169    1960
# 2577170    1970
# 2577171    1978
# 2577172    1966
# Name: tari, Length: 2577173, dtype: int64

# %%
df['tari'] = df['or_amis_tari'].apply(lambda x: int(x[-4:]))
df['tari']
df

# %%
df['tariq'] = 2024 - df['tari']

# %%
df[df['anun'] == 'Հայկ']['tariq'].max()
# Out:
# 103

# %%
df[df['anun'] == 'Մկրտիչ']['tariq'].max()
# Out:
# 100

# %%
max_tariq = df["tariq"].max()

print(max_tariq)
# Out:
# 117

# %%
df['tariq'] == max_tariq
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2577168    False
# 2577169    False
# 2577170    False
# 2577171    False
# 2577172    False
# Name: tariq, Length: 2577173, dtype: bool

# %%
df[df['tariq'] == max_tariq]
# Out:
#          azganun      anun haeranun or_amis_tari   marz   hamaenq bnakavaer  \
# 1676101  Ավագյան  Մարիամիկ   Արտոյի   01/07/1907  ՇԻՐԱԿ  ԱՋԱՓՆՅԱԿ       NaN
#
#                           hasce  taracq texamas  tari  tariq
# 1676101  Բաղյան 1 Նրբ.   2   47      31    7/21  1907    117

# %% [markdown]
# Ով է ամենատարեց մարդը

# %%
max_age = df['tariq'].max()
print(max_age)

df[df['tariq'] == max_age]
# Out:
# 116
#          azganun      anun haeranun or_amis_tari   marz  hamaenq bnakavaer  \
# 1676101  Ավագյան  Մարիամիկ   Գագիկի   01/07/1907  ՇԻՐԱԿ  ԿԵՆՏՐՈՆ       NaN
#
#                           hasce  taracq texamas  tari  tariq
# 1676101  Բաղյան 1 Նրբ.   1   22      31   11/35  1907    116

# %% [markdown]
# Քանի 47 տարեկան Մկրտիչ  կա

# %%
len(df[(df['tariq']==48) & (df['anun']=='Մկրտիչ')])
# Out:
# 53

# %%
df['or_amis_tari'].value_counts()
# Out:
# or_amis_tari
# 00/00/1936    1151
# 00/00/1937    1103
# 00/00/1938    1084
# 00/00/1935    1019
# 00/00/1939     984
#               ...
# 26/10/1923       1
# 11/07/1929       1
# 27/01/1923       1
# 02/01/1924       1
# 24/12/1924       1
# Name: count, Length: 28659, dtype: int64

# %% [markdown]
# ## Խմբավորում (groupby)

# %%
grouped = df.groupby('marz')
grouped

# %%
for name, group in grouped:
    print (name)
    print (group.head(1))
    print('\n')
    # break
# Out:
# ԱՐԱԳԱԾՈՏՆ
#           azganun  anun haeranun or_amis_tari       marz    hamaenq bnakavaer  \
# 187827  Առաքելյան  Վահե  Կարլենի   24/02/1981  ԱՐԱԳԱԾՈՏՆ  ԳԵՂԱՄԱՍԱՐ       NaN
#
#               hasce  taracq texamas  tari  tariq
# 187827  7/2 Փ.   11       4    4/44  1981     43
#
#
# ԱՐԱՐԱՏ
#        azganun    anun haeranun or_amis_tari    marz hamaenq bnakavaer  \
# 91503  Հովեյան  Սուրեն   Նորիկի   26/09/1988  ԱՐԱՐԱՏ  ՕՇԱԿԱՆ       NaN
#
#                  hasce  taracq texamas  tari  tariq
# 91503  Ծերենցի Փ.   50      22   11/49  1988     36
#
#
# ԱՐՄԱՎԻՐ
#         azganun     anun haeranun or_amis_tari     marz  hamaenq bnakavaer  \
# 91489  Շախզադով  Գեննադի  Սեդրակի   29/03/1978  ԱՐՄԱՎԻՐ  ՀՐԱԶԴԱՆ       NaN
#
#                               hasce  taracq texamas  tari  tariq
# 91489  Գր. Լուսավորիչի Փ.   39   27      22   11/31  1978     46
#
#
# ԳԵՂԱՐՔՈՒՆԻՔ
#            azganun   anun haeranun or_amis_tari         marz          hamaenq  \
# 187876  Հայրումյան  Արսեն  Գեւորգի   23/04/1970  ԳԵՂԱՐՔՈՒՆԻՔ  ՔԱՆԱՔԵՌ-ԶԵՅԹՈՒՆ
#
#        bnakavaer       hasce  taracq texamas  tari  tariq
# 187876       NaN  18 Փ.   23       4   38/09  1970     54
#
#
# ԵՐԵՎԱՆ
#            azganun    anun haeranun or_amis_tari    marz   hamaenq bnakavaer  \
# 45892  Մնացականյան  Հասմիկ   Արսենի   01/06/1968  ԵՐԵՎԱՆ  ԷՐԵԲՈՒՆԻ       NaN
#
#                        hasce  taracq texamas  tari  tariq
# 45892  Չարենց Թղմ.   12   17      28   29/02  1968     56
#
#
# ԼՈՌԻ
#         azganun    anun haeranun or_amis_tari  marz   hamaenq bnakavaer  \
# 46069  Ղազարյան  Նարինե  Ռուբենի   06/06/2003  ԼՈՌԻ  ՄԵՐՁԱՎԱՆ       NaN
#
#                          hasce  taracq texamas  tari  tariq
# 46069  Նորաշեն Թղմ.   15   102      22   22/09  2003     21
#
#
# ԿՈՏԱՅՔ
#          azganun   anun haeranun or_amis_tari    marz   hamaenq bnakavaer  \
# 0  Հարությունյան  Կարեն  Գրիգորի   14/11/1997  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ       NaN
#
#                         hasce  taracq texamas  tari  tariq
# 0  Համբարձումյան Փ.   14   33      28   22/22  1997     27
#
#
# ՇԻՐԱԿ
#         azganun    anun   haeranun or_amis_tari   marz   hamaenq bnakavaer  \
# 45828  Մարտոյան  Հասմիկ  Վարազդատի   15/09/1977  ՇԻՐԱԿ  ԽԱՇԹԱՌԱԿ       NaN
#
#           hasce  taracq texamas  tari  tariq
# 45828  1 Փ.   9      28   15/03  1977     47
#
#
# ՍՅՈՒՆԻՔ
#         azganun   anun haeranun or_amis_tari     marz   hamaenq bnakavaer  \
# 187855  Բաբայան  Լիլիթ  Սուրենի   29/04/1993  ՍՅՈՒՆԻՔ  ԳԵՂՀՈՎԻՏ       NaN
#
#                     hasce  taracq texamas  tari  tariq
# 187855  Ադոնցի Փ.   1   8       4   30/08  1993     31
#
#
# ՎԱՅՈՑ ՁՈՐ
#               azganun   anun     haeranun or_amis_tari       marz   hamaenq  \
# 254580  Հարությունյան  Աշխեն  Հարությունի   12/09/1964  ՎԱՅՈՑ ՁՈՐ  ԱԼԱՎԵՐԴԻ
#
#        bnakavaer             hasce  taracq texamas  tari  tariq
# 254580       NaN  Տավրոս 4 Փ.   11      17    6/39  1964     60
#
#
# ՏԱՎՈՒՇ
#        azganun    anun haeranun or_amis_tari    marz hamaenq bnakavaer  \
# 45789  Աղասյան  Արթուր   Կամոյի   21/11/1980  ՏԱՎՈՒՇ    ՎԵԴԻ       NaN
#
#                    hasce  taracq texamas  tari  tariq
# 45789  Ծերենցի Փ.   75/6      28   23/03  1980     44

# %%
df.groupby('anun').tariq.mean().sort_values()
# Out:
# anun
# Անգելիկա Սուզաննա     21.0
# Բրենդա                21.0
# Անէլլա                21.0
# Եւանգելոս             21.0
# Հայկ Արեգ             21.0
#                      ...
# Հեղինո               104.0
# Ուղդա                104.0
# Հադիա                105.0
# Խորիլ                107.0
# Վարսի                109.0
# Name: tariq, Length: 22062, dtype: float64

# %%
df['anvan_erkarutun'] = df['anun'].apply(lambda x: len(x))
df['anvan_erkarutun'] = df['anun'].apply(len)

df
# results = df.groupby('tari')['anvan_erkarutun'].mean()
# results
# Out:
#                azganun        anun    haeranun or_amis_tari    marz  \
# 0        Հարությունյան       Կարեն     Գրիգորի   14/11/1997  ԿՈՏԱՅՔ
# 1            Աղաջանյան      Կարինե    Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ
# 2        Հարությունյան  Հարություն       Աշոտի   29/10/1986  ԿՈՏԱՅՔ
# 3           Ալեքսանյան      Համեստ      Շամիրի   24/10/1954  ԿՈՏԱՅՔ
# 4        Հարությունյան       Շաքար       Արամի   01/01/1959  ԿՈՏԱՅՔ
# ...                ...         ...         ...          ...     ...
# 2577168     Շահվերդյան         Ալա     Սեդրակի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան      Կարինե  Անուշավանի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան      Անահիտ      Լեւոնի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան      Նարինե     Ռուբենի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան      Գայանե       Էդիկի   24/04/1966    ԼՈՌԻ
#
#            hamaenq bnakavaer                       hasce  taracq texamas  \
# 0         ՇԵՆԳԱՎԻԹ       NaN  Համբարձումյան Փ.   14   33      28   22/22
# 1          ԱՐՏԻՄԵՏ       NaN        Իսակովի Փ.   99   15      28    5/08
# 2           ԻՋԵՎԱՆ       NaN          Չեխովի Փ.   34   3      28   14/03
# 3          ՌԱՆՉՊԱՐ       NaN        Գուսան Աշոտի Փ.   11      28   32/38
# 4          ԱԲՈՎՅԱՆ       NaN        Պռոշյան Փ.   10   27      28   13/15
# ...            ...       ...                         ...     ...     ...
# 2577168     ՍԻՍԻԱՆ       NaN      Շահումյան Փ.   97   46      23   18/69
# 2577169  ՇԱՀՈՒՄՅԱՆ       NaN      Բ. Մարտիրոսյան Փ.   23      23   13/54
# 2577170     ՍԻՍԻԱՆ       NaN        Թումանյան 3 Նրբ.   8      23    6/39
# 2577171   ՇԵՆԳԱՎԻԹ       NaN                    9 Փ.   1      23   33/11
# 2577172       ՎԵԴԻ       NaN     Վիլնյուսի Փ.   115   40      23   32/23
#
#          tari  tariq  anvan_erkarutun
# 0        1997     27                5
# 1        1964     60                6
# 2        1986     38               10
# 3        1954     70                6
# 4        1959     65                5
# ...       ...    ...              ...
# 2577168  1987     37                3
# 2577169  1960     64                6
# 2577170  1970     54                6
# 2577171  1978     46                6
# 2577172  1966     58                6
#
# [2577173 rows x 13 columns]

# %%
results = df.groupby('tari')['anvan_erkarutun'].mean()
results
# Out:
# tari
# 1907    8.000000
# 1908    4.000000
# 1911    7.000000
# 1912    6.666667
# 1913    6.000000
#           ...
# 1999    5.623622
# 2000    5.598365
# 2001    5.602270
# 2002    5.566442
# 2003    5.542347
# Name: anvan_erkarutun, Length: 95, dtype: float64

# %%
results.plot()
# Out:
# <Axes: xlabel='tari'>

# %%
df_after_1920 = df[df.tari > 1920]
results = df_after_1920.groupby('tari')['anvan_erkarutun'].mean()
results.plot()
# Out:
# <Axes: xlabel='tari'>

# %%
df.groupby(['marz', 'anun']).tariq.max()
# Out:
# marz       anun
# ԱՐԱԳԱԾՈՏՆ  0լգա        85
#            Աարոն       39
#            Աբաս        78
#            Աբգար       96
#            Աբել        64
#                        ..
# ՏԱՎՈՒՇ     Ֆրիմա       84
#            Ֆրոնտիկ     83
#            Ֆրունզե     84
#            Ֆրունզիկ    92
#            Ֆրուսյա     85
# Name: tariq, Length: 55966, dtype: int64

# %%
df.head()
# Out:
#          azganun        anun    haeranun or_amis_tari    marz   hamaenq  \
# 0  Հարությունյան       Կարեն      Զավենի   14/11/1997  ԿՈՏԱՅՔ  ԱՅԳԵԶԱՐԴ
# 1      Աղաջանյան      Կարինե      Արսենի   14/08/1964  ԿՈՏԱՅՔ   ԳՅՈՒՄՐԻ
# 2  Հարությունյան  Հարություն  Հովհաննեսի   29/10/1986  ԿՈՏԱՅՔ   ԱՐԱԲԿԻՐ
# 3     Ալեքսանյան      Համեստ     Մաքսիմի   24/10/1954  ԿՈՏԱՅՔ   ԶՈԼԱՔԱՐ
# 4  Հարությունյան       Շաքար       Ենոքի   01/01/1959  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ
#
#   bnakavaer                       hasce  taracq texamas  tari  tariq  \
# 0       NaN                1 Փ.   6   2      28   29/06  1997     26
# 1       NaN    Մոլդովական Փ.   2/1   41      28   13/32  1964     59
# 2       NaN                  12 Փ.   21      28   19/15  1986     37
# 3       NaN  Ավան Առինջ 1 Մկրշ.   4   5      28   23/11  1954     69
# 4       NaN    Նոր Արեշ 11 Փ.   72   17      28    3/27  1959     64
#
#    anvan_erkarutun
# 0                5
# 1                6
# 2               10
# 3                6
# 4                5

# %% [markdown]
# ## Pivot table

# %%
help(df.pivot_table)

# %%
old_df = df.copy()

# %%
names = ['Հայկ', "Մկրտիչ"]

# %%
df = df[df.anun.isin(names)]
df
# Out:
#               azganun    anun   haeranun or_amis_tari    marz   hamaenq  \
# 45           Ղազարյան    Հայկ     Խաչիկի   28/03/1992  ԿՈՏԱՅՔ  ՄԱՐՄԱՇԵՆ
# 61           Ղազարյան    Հայկ  Խաչատուրի   28/07/1996  ԿՈՏԱՅՔ   ՎԱՆԱՁՈՐ
# 149      Ղավալբաբունց    Հայկ     Հրանտի   26/10/1981  ԿՈՏԱՅՔ  ԳԵՂԱՆՈՒՇ
# 311        Մաթեւոսյան    Հայկ    Հայրիկի   22/10/1998  ԿՈՏԱՅՔ      ԱՎԱՆ
# 312        Մաթեւոսյան    Հայկ   Նարիբեկի   09/08/1949  ԿՈՏԱՅՔ  ՄԱՐՄԱՇԵՆ
# ...               ...     ...        ...          ...     ...       ...
# 2576752     Գրիգորյան    Հայկ    Գեւորգի   20/12/1972    ԼՈՌԻ   ԳՅՈՒՄՐԻ
# 2576821        Ազոյան  Մկրտիչ   Սպարտակի   12/02/1980    ԼՈՌԻ     ՄԵՂՐԻ
# 2576913      Աֆրիկյան    Հայկ    Հունանի   28/02/1993    ԼՈՌԻ  ՆՈՐ ՆՈՐՔ
# 2577122       Խամոյան    Հայկ   Արեւշատի   02/11/1988    ԼՈՌԻ   ՄԵԾԱՄՈՐ
# 2577138     Մարուքյան  Մկրտիչ    Սերգեյի   12/02/1992    ԼՈՌԻ   ՎԱՆԱՁՈՐ
#
#         bnakavaer                       hasce  taracq texamas
# 45            NaN              Մռավյան Փ.   4      28   13/10
# 61            NaN                   4 Փ.   41      28   27/05
# 149           NaN       Լմբատ 1 Թղմ.   14   7      28    2/34
# 311           NaN                    9 Փ.   5      28   10/22
# 312           NaN       Ադոնցի Փ.   17/2   27      28   12/25
# ...           ...                         ...     ...     ...
# 2576752       NaN             Աբեղյան Փ.   35      23   24/58
# 2576821       NaN         Մանանդյան Նրբ.   18      23   37/15
# 2576913       NaN        Քոչարյան Փ.   4   45      23   36/20
# 2577122       NaN  Եղ. Թադեւոսյան Փ.   2   49      23    7/16
# 2577138       NaN             Մաշտոցի Փ.   15      23   10/01
#
# [22692 rows x 10 columns]

# %% [markdown]
# ըստ մարզի անվան միջին տարիքը

# %%
pivot_table = df.pivot_table(index='marz', columns='anun', values='tariq')
pivot_table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 pivot_table = df.pivot_table(index='marz', columns='anun', values='tariq')
#       2 pivot_table
#
# File c:\Users\hayk_\.conda\envs\thesis\lib\site-packages\pandas\core\frame.py:9516, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9499 @Substitution("")
#    9500 @Appender(_shared_docs["pivot_table"])
#    9501 def pivot_table(
#    (...)
#    9512     sort: bool = True,
#    9513 ) -> DataFrame:
#    9514     from pandas.core.reshape.pivot import pivot_table
# -> 9516     return pivot_table(
#    9517         self,
#    9518         values=values,
#    9519         index=index,
#    9520         columns=columns,
#    9521         aggfunc=aggfunc,
#    9522         fill_value=fill_value,
#    9523         margins=margins,
#    9524         dropna=dropna,
#    9525         margins_name=margins_name,
#    9526         observed=observed,
#    9527         sort=sort,
#    9528     )
#
# File c:\Users\hayk_\.conda\envs\thesis\lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\hayk_\.conda\envs\thesis\lib\site-packages\pandas\core\reshape\pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'tariq'

# %% [markdown]
# ըստ մարզի անունը ունեղոց ամենածեր մարդու տարիքը

# %%
pivot_table = df.pivot_table(index='marz', columns='anun', values='tariq', aggfunc="max")
pivot_table
# Out:
# anun         Հայկ  Մկրտիչ
# marz
# ԱՐԱԳԱԾՈՏՆ      92     100
# ԱՐԱՐԱՏ         92      98
# ԱՐՄԱՎԻՐ        96      97
# ԳԵՂԱՐՔՈՒՆԻՔ    98      84
# ԵՐԵՎԱՆ         96     100
# ԼՈՌԻ          103      95
# ԿՈՏԱՅՔ         92      92
# ՇԻՐԱԿ          93      97
# ՍՅՈՒՆԻՔ        96      78
# ՎԱՅՈՑ ՁՈՐ      77      89
# ՏԱՎՈՒՇ         89      84

# %% [markdown]
# Նույնը բոլոր անունների համար

# %%
pivot_table = old_df.pivot_table(index='marz', columns='anun', values='tariq', aggfunc='max')
pivot_table
# Out:
# anun         0լգա  Աարոն  Աբալ  Աբայկա  Աբաս  Աբավեն  Աբաքինա  Աբբաս  Աբգար  \
# marz
# ԱՐԱԳԱԾՈՏՆ    85.0   39.0   NaN     NaN  78.0     NaN      NaN    NaN   96.0
# ԱՐԱՐԱՏ        NaN    NaN   NaN     NaN  63.0     NaN      NaN   71.0   75.0
# ԱՐՄԱՎԻՐ       NaN    NaN   NaN     NaN  77.0     NaN      NaN    NaN   86.0
# ԳԵՂԱՐՔՈՒՆԻՔ   NaN    NaN   NaN     NaN   NaN     NaN      NaN    NaN   94.0
# ԵՐԵՎԱՆ        NaN   55.0   NaN     NaN   NaN     NaN     82.0    NaN   76.0
# ԼՈՌԻ          NaN    NaN   NaN     NaN  51.0     NaN      NaN    NaN   85.0
# ԿՈՏԱՅՔ        NaN   60.0   NaN     NaN  67.0     NaN      NaN   82.0   77.0
# ՇԻՐԱԿ         NaN   56.0   NaN     NaN  25.0     NaN      NaN    NaN   74.0
# ՍՅՈՒՆԻՔ       NaN    NaN  69.0     NaN   NaN    89.0      NaN    NaN   89.0
# ՎԱՅՈՑ ՁՈՐ     NaN    NaN   NaN     NaN   NaN     NaN      NaN    NaN   67.0
# ՏԱՎՈՒՇ        NaN    NaN   NaN    91.0   NaN     NaN      NaN    NaN   73.0
#
# anun         Աբդալ  ...  Ֆրուժետա  Ֆրուլենտ  Ֆրունզ  Ֆրունզե  Ֆրունզիկ  \
# marz                ...
# ԱՐԱԳԱԾՈՏՆ      NaN  ...      84.0       NaN    30.0     83.0      87.0
# ԱՐԱՐԱՏ         NaN  ...      88.0       NaN    82.0     93.0      85.0
# ԱՐՄԱՎԻՐ        NaN  ...      30.0       NaN    71.0     89.0      90.0
# ԳԵՂԱՐՔՈՒՆԻՔ    NaN  ...       NaN      77.0    87.0     93.0      93.0
# ԵՐԵՎԱՆ        90.0  ...      77.0       NaN    72.0     91.0      91.0
# ԼՈՌԻ           NaN  ...       NaN       NaN    45.0     89.0      92.0
# ԿՈՏԱՅՔ         NaN  ...       NaN       NaN    81.0     88.0      86.0
# ՇԻՐԱԿ          NaN  ...      89.0       NaN    23.0     95.0      89.0
# ՍՅՈՒՆԻՔ        NaN  ...       NaN       NaN    88.0     91.0      76.0
# ՎԱՅՈՑ ՁՈՐ      NaN  ...       NaN       NaN    73.0     88.0      96.0
# ՏԱՎՈՒՇ         NaN  ...       NaN       NaN     NaN     84.0      92.0
#
# anun         Ֆրունզյա  Ֆրուսիա  Ֆրուսյա  Ֆրրիկ  Ֆօֆօ
# marz
# ԱՐԱԳԱԾՈՏՆ         NaN      NaN      NaN    NaN   NaN
# ԱՐԱՐԱՏ            NaN      NaN      NaN    NaN   NaN
# ԱՐՄԱՎԻՐ           NaN     89.0     46.0    NaN   NaN
# ԳԵՂԱՐՔՈՒՆԻՔ       NaN      NaN      NaN   65.0   NaN
# ԵՐԵՎԱՆ           78.0      NaN      NaN    NaN  89.0
# ԼՈՌԻ              NaN      NaN      NaN    NaN   NaN
# ԿՈՏԱՅՔ           89.0      NaN      NaN   59.0   NaN
# ՇԻՐԱԿ             NaN      NaN      NaN    NaN   NaN
# ՍՅՈՒՆԻՔ           NaN      NaN      NaN    NaN   NaN
# ՎԱՅՈՑ ՁՈՐ         NaN      NaN      NaN    NaN   NaN
# ՏԱՎՈՒՇ            NaN      NaN     85.0    NaN   NaN
#
# [11 rows x 22061 columns]

# %% [markdown]
# Դատարկ արժեքները լրացննեք

# %%
pivot_table = old_df.pivot_table(index='marz', columns='anun', values='tariq',
                                 aggfunc='max', fill_value="չկա")
pivot_table
# Out:
# anun        0լգա Աարոն Աբալ Աբայկա Աբաս Աբավեն Աբաքինա Աբբաս  Աբգար Աբդալ  \
# marz
# ԱՐԱԳԱԾՈՏՆ     85    39  չկա    չկա   78    չկա     չկա   չկա     96   չկա
# ԱՐԱՐԱՏ       չկա   չկա  չկա    չկա   63    չկա     չկա    71     75   չկա
# ԱՐՄԱՎԻՐ      չկա   չկա  չկա    չկա   77    չկա     չկա   չկա     86   չկա
# ԳԵՂԱՐՔՈՒՆԻՔ  չկա   չկա  չկա    չկա  չկա    չկա     չկա   չկա     94   չկա
# ԵՐԵՎԱՆ       չկա    55  չկա    չկա  չկա    չկա      82   չկա     76    90
# ԼՈՌԻ         չկա   չկա  չկա    չկա   51    չկա     չկա   չկա     85   չկա
# ԿՈՏԱՅՔ       չկա    60  չկա    չկա   67    չկա     չկա    82     77   չկա
# ՇԻՐԱԿ        չկա    56  չկա    չկա   25    չկա     չկա   չկա     74   չկա
# ՍՅՈՒՆԻՔ      չկա   չկա   69    չկա  չկա     89     չկա   չկա     89   չկա
# ՎԱՅՈՑ ՁՈՐ    չկա   չկա  չկա    չկա  չկա    չկա     չկա   չկա     67   չկա
# ՏԱՎՈՒՇ       չկա   չկա  չկա     91  չկա    չկա     չկա   չկա     73   չկա
#
# anun         ... Ֆրուժետա Ֆրուլենտ Ֆրունզ Ֆրունզե Ֆրունզիկ Ֆրունզյա Ֆրուսիա  \
# marz         ...
# ԱՐԱԳԱԾՈՏՆ    ...       84      չկա     30      83       87      չկա     չկա
# ԱՐԱՐԱՏ       ...       88      չկա     82      93       85      չկա     չկա
# ԱՐՄԱՎԻՐ      ...       30      չկա     71      89       90      չկա      89
# ԳԵՂԱՐՔՈՒՆԻՔ  ...      չկա       77     87      93       93      չկա     չկա
# ԵՐԵՎԱՆ       ...       77      չկա     72      91       91       78     չկա
# ԼՈՌԻ         ...      չկա      չկա     45      89       92      չկա     չկա
# ԿՈՏԱՅՔ       ...      չկա      չկա     81      88       86       89     չկա
# ՇԻՐԱԿ        ...       89      չկա     23      95       89      չկա     չկա
# ՍՅՈՒՆԻՔ      ...      չկա      չկա     88      91       76      չկա     չկա
# ՎԱՅՈՑ ՁՈՐ    ...      չկա      չկա     73      88       96      չկա     չկա
# ՏԱՎՈՒՇ       ...      չկա      չկա    չկա      84       92      չկա     չկա
#
# anun        Ֆրուսյա Ֆրրիկ Ֆօֆօ
# marz
# ԱՐԱԳԱԾՈՏՆ       չկա   չկա  չկա
# ԱՐԱՐԱՏ          չկա   չկա  չկա
# ԱՐՄԱՎԻՐ          46   չկա  չկա
# ԳԵՂԱՐՔՈՒՆԻՔ     չկա    65  չկա
# ԵՐԵՎԱՆ          չկա   չկա   89
# ԼՈՌԻ            չկա   չկա  չկա
# ԿՈՏԱՅՔ          չկա    59  չկա
# ՇԻՐԱԿ           չկա   չկա  չկա
# ՍՅՈՒՆԻՔ         չկա   չկա  չկա
# ՎԱՅՈՑ ՁՈՐ       չկա   չկա  չկա
# ՏԱՎՈՒՇ           85   չկա  չկա
#
# [11 rows x 22061 columns]

# %% [markdown]
# Մի քանի ագրեգացիա

# %%
import numpy as np

# %%
pivot_table = df.pivot_table(index='marz', columns='anun', values='tariq',
                             aggfunc=["max", lambda x: sum(x)/len(x), np.sum])
pivot_table
# Out:
# <ipython-input-111-c2bdda964dca>:1: FutureWarning: The provided callable <function sum at 0x7f7335b36e60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot_table = df.pivot_table(index='marz', columns='anun', values='tariq',
#              max          <lambda>                sum
# anun        Հայկ Մկրտիչ       Հայկ     Մկրտիչ    Հայկ Մկրտիչ
# marz
# ԱՐԱԳԱԾՈՏՆ     92    100  42.060936  50.654676   38654  14082
# ԱՐԱՐԱՏ        92     98  41.310781  50.982301   55563  11522
# ԱՐՄԱՎԻՐ       96     97  42.148124  52.958042   65161  22719
# ԳԵՂԱՐՔՈՒՆԻՔ   98     84  44.828068  47.598291   61011  11138
# ԵՐԵՎԱՆ        96    100  41.606372  54.487575  295114  63587
# ԼՈՌԻ         103     95  42.354926  51.713147   62770  12980
# ԿՈՏԱՅՔ        92     92  40.730730  51.748344   79262  15628
# ՇԻՐԱԿ         93     97  41.736246  50.349189   51586  46573
# ՍՅՈՒՆԻՔ       96     78  36.904948  50.603774   28343   2682
# ՎԱՅՈՑ ՁՈՐ     77     89  42.296399  53.944444   15269   2913
# ՏԱՎՈՒՇ        89     84  40.586510  49.676471   27680   1689

# %% [markdown]
# Մի քանի սյուն

# %%
pivot_table = df.pivot_table(index='marz', columns=['anun', 'azganun'], values='tariq',
                             aggfunc="max")
pivot_table
# Out:
# anun           Հայկ                                                          \
# azganun     Աբազյան Աբաղյան Աբաջյան Աբգարյան Աբելյան Աբեջյան Աբէլեան Աբոյան
# marz
# ԱՐԱԳԱԾՈՏՆ       NaN     NaN     NaN     47.0     NaN     NaN     NaN    NaN
# ԱՐԱՐԱՏ          NaN     NaN     NaN     66.0    38.0     NaN     NaN    NaN
# ԱՐՄԱՎԻՐ         NaN     NaN    43.0     54.0    23.0     NaN     NaN    NaN
# ԳԵՂԱՐՔՈՒՆԻՔ     NaN     NaN     NaN      NaN     NaN     NaN     NaN    NaN
# ԵՐԵՎԱՆ         50.0     NaN    44.0     46.0    43.0    39.0    63.0    NaN
# ԼՈՌԻ           69.0     NaN     NaN     62.0     NaN     NaN     NaN   40.0
# ԿՈՏԱՅՔ          NaN     NaN     NaN     42.0     NaN     NaN     NaN    NaN
# ՇԻՐԱԿ           NaN     NaN    31.0     62.0     NaN     NaN     NaN    NaN
# ՍՅՈՒՆԻՔ         NaN     NaN     NaN     71.0     NaN     NaN     NaN    NaN
# ՎԱՅՈՑ ՁՈՐ       NaN    33.0     NaN     25.0    57.0     NaN     NaN    NaN
# ՏԱՎՈՒՇ         61.0     NaN     NaN     34.0     NaN     NaN     NaN    NaN
#
# anun                        ...  Մկրտիչ                               \
# azganun     Աբովյան Աբունց  ... Օքրոյան Ֆախուրյան Ֆահրադյան Ֆարիզյան
# marz                        ...
# ԱՐԱԳԱԾՈՏՆ       NaN    NaN  ...     NaN       NaN       NaN     37.0
# ԱՐԱՐԱՏ          NaN    NaN  ...     NaN      32.0      55.0      NaN
# ԱՐՄԱՎԻՐ        40.0    NaN  ...     NaN       NaN      24.0      NaN
# ԳԵՂԱՐՔՈՒՆԻՔ     NaN    NaN  ...     NaN       NaN       NaN      NaN
# ԵՐԵՎԱՆ         76.0    NaN  ...    78.0       NaN       NaN      NaN
# ԼՈՌԻ           47.0    NaN  ...     NaN       NaN       NaN      NaN
# ԿՈՏԱՅՔ         45.0    NaN  ...     NaN       NaN       NaN      NaN
# ՇԻՐԱԿ           NaN    NaN  ...     NaN       NaN       NaN      NaN
# ՍՅՈՒՆԻՔ         NaN   27.0  ...     NaN       NaN       NaN      NaN
# ՎԱՅՈՑ ՁՈՐ       NaN    NaN  ...     NaN       NaN       NaN      NaN
# ՏԱՎՈՒՇ         56.0    NaN  ...     NaN       NaN       NaN      NaN
#
# anun
# azganun     Ֆարմանյան Ֆենդյան Ֆեսչյան Ֆռանգուլյան Ֆրանգուլյան Ֆրիդման-Շչեպակին
# marz
# ԱՐԱԳԱԾՈՏՆ         NaN     NaN     NaN         NaN         NaN              NaN
# ԱՐԱՐԱՏ            NaN     NaN     NaN         NaN         NaN             47.0
# ԱՐՄԱՎԻՐ           NaN     NaN     NaN         NaN         NaN              NaN
# ԳԵՂԱՐՔՈՒՆԻՔ       NaN     NaN     NaN         NaN         NaN              NaN
# ԵՐԵՎԱՆ           55.0    58.0    69.0         NaN        71.0              NaN
# ԼՈՌԻ              NaN     NaN     NaN         NaN         NaN              NaN
# ԿՈՏԱՅՔ            NaN     NaN     NaN         NaN         NaN              NaN
# ՇԻՐԱԿ             NaN     NaN     NaN        43.0         NaN              NaN
# ՍՅՈՒՆԻՔ           NaN     NaN     NaN         NaN         NaN              NaN
# ՎԱՅՈՑ ՁՈՐ         NaN     NaN     NaN         NaN         NaN              NaN
# ՏԱՎՈՒՇ            NaN     NaN     NaN         NaN         NaN              NaN
#
# [11 rows x 3287 columns]

# %% [markdown]
# Մի քանի ինդեքս

# %%
pivot_table = df.pivot_table(index=['marz', 'azganun'], values='tariq', aggfunc=lambda x: sum(x) / len(x))
print(pivot_table)
# Out:
#                        tariq
# marz      azganun
# ԱՐԱԳԱԾՈՏՆ Աբգարյան    46.500
#           Աբրահամյան  37.375
#           Ադամյան     51.500
#           Ադիբեկյան   47.000
#           Ազատյան     50.200
# ...                      ...
# ՏԱՎՈՒՇ    Քոսակյան    42.000
#           Օթարյան     27.500
#           Օհանյան     38.800
#           Օրդինյան    29.500
#           Օրդյան      29.000
#
# [5344 rows x 1 columns]

# %% [markdown]
# Marginներով

# %%
pivot_table = df.pivot_table(index='marz', columns='anun', values='tariq',
                            aggfunc="mean", margins=True,  margins_name="ընդհանուր")
pivot_table
# Out:
# anun              Հայկ     Մկրտիչ  ընդհանուր
# marz
# ԱՐԱԳԱԾՈՏՆ    42.060936  50.654676  44.056809
# ԱՐԱՐԱՏ       41.310781  50.982301  42.702101
# ԱՐՄԱՎԻՐ      42.148124  52.958042  44.496203
# ԳԵՂԱՐՔՈՒՆԻՔ  44.828068  47.598291  45.234483
# ԵՐԵՎԱՆ       41.606372  54.487575  43.426271
# ԼՈՌԻ         42.354926  51.713147  43.710329
# ԿՈՏԱՅՔ       40.730730  51.748344  42.210854
# ՇԻՐԱԿ        41.736246  50.349189  45.422952
# ՍՅՈՒՆԻՔ      36.904948  50.603774  37.789281
# ՎԱՅՈՑ ՁՈՐ    42.296399  53.944444  43.812048
# ՏԱՎՈՒՇ       40.586510  49.676471  41.018156
# ընդհանուր    41.646459  51.989122  43.448176

# %% [markdown]
# ուրիշ օրինակ

# %%
old_df
# Out:
#                azganun        anun   haeranun or_amis_tari    marz  \
# 0        Հարությունյան       Կարեն    Մկրտիչի   14/11/1997  ԿՈՏԱՅՔ
# 1            Աղաջանյան      Կարինե  Նարինբեկի   14/08/1964  ԿՈՏԱՅՔ
# 2        Հարությունյան  Հարություն    Սամվելի   29/10/1986  ԿՈՏԱՅՔ
# 3           Ալեքսանյան      Համեստ   Պավլուշի   24/10/1954  ԿՈՏԱՅՔ
# 4        Հարությունյան       Շաքար     Վանիկի   01/01/1959  ԿՈՏԱՅՔ
# ...                ...         ...        ...          ...     ...
# 2577168     Շահվերդյան         Ալա   Սանասարի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան      Կարինե    Ստեփանի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան      Անահիտ   Միխայելի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան      Նարինե    Սուրենի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան      Գայանե     Սոսինի   24/04/1966    ԼՈՌԻ
#
#             hamaenq bnakavaer                       hasce  taracq texamas  \
# 0            ՆԻԶԱՄԻ       NaN     Շիրվանզադեի Փ.   5   30      28   25/08
# 1        ՍՏԵՓԱՆԱՎԱՆ       NaN    Շերամի 2 Թղմ.   1-3   82      28   14/47
# 2           ԿԵՆՏՐՈՆ       NaN  Նոր Նորք 8 Զնգվ.   33   22      28   21/27
# 3        ՎԱՂԱՐՇԱՊԱՏ       NaN  Հաղթանակ 2 Փ. 1 Նրբ.   1/3      28   35/20
# 4             ԿԱՊԱՆ       NaN      Հ/Ա բ2 Թղմ.   139   10      28    8/36
# ...             ...       ...                         ...     ...     ...
# 2577168      ԱԽԹԱԼԱ       NaN         1 Փ. 1 Նրբ.   9   3      23   22/05
# 2577169     ՍԱՐԱՄԵՋ       NaN         Մաշտոցի Փ.   1   40      23   23/44
# 2577170     ՎԱՆԱՁՈՐ       NaN      Շահումյան Փ.   59   13      23   12/12
# 2577171     ԳՅՈՒՄՐԻ       NaN                5 Փ.   194/1      23   23/31
# 2577172     ՋԱՆՖԻԴԱ       NaN      Վիլնյուսի Փ.   85   67      23   19/28
#
#          tari  tariq
# 0        1997     26
# 1        1964     59
# 2        1986     37
# 3        1954     69
# 4        1959     64
# ...       ...    ...
# 2577168  1987     36
# 2577169  1960     63
# 2577170  1970     53
# 2577171  1978     45
# 2577172  1966     57
#
# [2577173 rows x 12 columns]

# %%
list(old_df.columns)
# Out:
# ['azganun',
#  'anun',
#  'haeranun',
#  'or_amis_tari',
#  'marz',
#  'hamaenq',
#  'bnakavaer',
#  'hasce',
#  'taracq',
#  'texamas',
#  'tari',
#  'tariq']

# %%
old_df.sample(10)
# Out:
#                azganun     anun   haeranun or_amis_tari     marz  \
# 1187641      Առաքելյան   Քնարիկ  Սերյոժայի   01/07/1942   ԱՐԱՐԱՏ
# 1276268     Նիկողոսյան     Մերի     Վիտյաի   18/03/1986   ԿՈՏԱՅՔ
# 1655308      Մահլամյան  Փիրուզա    Մաքսիմի   07/11/1977    ՇԻՐԱԿ
# 703073   Հարությունյան     Արեգ   Խալիֆայի   23/11/1999   ԵՐԵՎԱՆ
# 1268311      Աթաբեկյան    Արմեն     Պյոտրի   15/12/1977   ՏԱՎՈՒՇ
# 1200858      Վարդանյան   Վարսիկ  Համազասպի   09/11/1958   ԱՐԱՐԱՏ
# 1842479      Հովսեփյան  Սաթենիկ    Վազգենի   12/08/1991   ԵՐԵՎԱՆ
# 1407539        Երեմյան     Սեդա  Համազասպի   20/03/1954  ԱՐՄԱՎԻՐ
# 1702150        Գոմցյան    Էդգար    Վազգենի   15/11/1994    ՇԻՐԱԿ
# 72100        Թումանյան     Ավագ    Հողմիկի   30/01/1947     ԼՈՌԻ
#
#                   hamaenq bnakavaer                         hasce  taracq  \
# 1187641  ՄԱԼԱԹԻԱ-ՍԵԲԱՍՏԻԱ       NaN           Նուբարաշեն 8 Փ.   4      11
# 1276268             ԿԱՊԱՆ       NaN        Չարենցի Փ.   3   20-21      26
# 1655308              ԱՎԱՆ       NaN      Լուսավորության Փ.   14/1      31
# 703073           ՇԵՆԳԱՎԻԹ       NaN            Մյասնիկյան Փ.   36       3
# 1268311            ՍԻՍԻԱՆ       NaN        Ռասկատլյան Փ.   1   35      37
# 1200858          ՆՈՐ ՆՈՐՔ       NaN     Ա. Ավետիսյան Փ.   67   27      11
# 1842479   ՔԱՆԱՔԵՌ-ԶԵՅԹՈՒՆ       NaN       Ազատամարտիկների Փ.   46      10
# 1407539          ՆՈՐ ՆՈՐՔ       NaN  Վ. Համբարձումյան Փ.   75   1      15
# 1702150       ԳԵՂԱՐՔՈՒՆԻՔ       NaN             11 Փ. 1 Փկղ.   11      31
# 72100            ԱՋԱՓՆՅԱԿ       NaN              Չարենցի Փ.   95Ա      22
#
#         texamas  tari  tariq  anvan_erkarutun
# 1187641    4/02  1942     82                6
# 1276268   13/29  1986     38                4
# 1655308   17/15  1977     47                7
# 703073    11/20  1999     25                4
# 1268311    4/53  1977     47                5
# 1200858   11/13  1958     66                6
# 1842479   30/63  1991     33                7
# 1407539   32/29  1954     70                4
# 1702150   23/32  1994     30                5
# 72100     28/21  1947     77                4

# %% [markdown]
# ## Missing value

# %%
import numpy as np
np.all(df.bnakavaer.isna())
# Out:
# np.False_

# %%
df[~df.bnakavaer.isna()] # ~ - not
# Out:
#                azganun    anun  haeranun or_amis_tari         marz  \
# 8816           Փիլոյան    Հայկ  Նարիբեկի   14/05/1979       ԿՈՏԱՅՔ
# 8952          Բադիկյան    Հայկ    Սարգսի   21/12/1986       ԿՈՏԱՅՔ
# 9381         Իսրաելյան  Մկրտիչ   Երվանդի   15/01/1962       ԿՈՏԱՅՔ
# 9646         Ուզունյան    Հայկ    Գագիկի   28/04/1984       ԿՈՏԱՅՔ
# 9774           Բաբայան    Հայկ   Մանուկի   12/10/1989       ԿՈՏԱՅՔ
# ...                ...     ...       ...          ...          ...
# 2367248       Մինասյան    Հայկ     Օնիկի   20/11/1988  ԳԵՂԱՐՔՈՒՆԻՔ
# 2367424        Ըխտոյան    Հայկ    Սարգսի   28/07/1972  ԳԵՂԱՐՔՈՒՆԻՔ
# 2367494       Գալստյան    Հայկ   Համլետի   16/06/1994  ԳԵՂԱՐՔՈՒՆԻՔ
# 2367516  Հարությունյան    Հայկ   Յուրիկի   18/05/1965  ԳԵՂԱՐՔՈՒՆԻՔ
# 2367632        Թամոյան    Հայկ   Սերժիկի   04/03/1958  ԳԵՂԱՐՔՈՒՆԻՔ
#
#                  hamaenq    bnakavaer                               hasce  \
# 8816             ԳՈՒԳԱՐՔ  ԲՅՈՒՐԵՂԱՎԱՆ                      Րաֆֆու Փ.   28
# 8952            ՆՈՐ ՆՈՐՔ  ԲՅՈՒՐԵՂԱՎԱՆ                            1 Փ.   6
# 9381     ՔԱՆԱՔԵՌ-ԶԵՅԹՈՒՆ  ԲՅՈՒՐԵՂԱՎԱՆ                           1 Փ.   29
# 9646          ՍԱՅԱԹ-ՆՈՎԱ  ԲՅՈՒՐԵՂԱՎԱՆ                Օգանովի Փ.   36   30
# 9774     ՔԱՆԱՔԵՌ-ԶԵՅԹՈՒՆ  ԲՅՈՒՐԵՂԱՎԱՆ                    Սուվորովի Փ.   3
# ...                  ...          ...                                 ...
# 2367248           ԵՂՎԱՐԴ     ԳԵՂՀՈՎԻՏ  Զաքարիա Քանաքեռցու Փ.   145/1   40
# 2367424             ՎԱՅՔ     ԳԵՂՀՈՎԻՏ               Շիրակի Խճղ.   66   16
# 2367494            ԳԱՎԱՌ     ԳԵՂՀՈՎԻՏ      Ավան Առինջ 2 Մկրշ.   1/17   31
# 2367516          ՀՆԱԲԵՐԴ     ԳԵՂՀՈՎԻՏ                   Հ. Սահյան Փ.   28
# 2367632  ՔԱՆԱՔԵՌ-ԶԵՅԹՈՒՆ     ԳԵՂՀՈՎԻՏ                    Դեմիրճյան Փ.   9
#
#          taracq texamas
# 8816         28    6/52
# 8952         28    9/35
# 9381         28    9/19
# 9646         28   14/08
# 9774         28    6/43
# ...         ...     ...
# 2367248      21   32/38
# 2367424      21    6/51
# 2367494      21   13/07
# 2367516      21   17/09
# 2367632      21    3/27
#
# [4455 rows x 10 columns]

# %%
df = old_df

df.head(2)
# Out:
#          azganun    anun  haeranun or_amis_tari    marz   hamaenq bnakavaer  \
# 0  Հարությունյան   Կարեն   Գրիգորի   14/11/1997  ԿՈՏԱՅՔ  ՇԵՆԳԱՎԻԹ       NaN
# 1      Աղաջանյան  Կարինե  Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ   ԱՐՏԻՄԵՏ       NaN
#
#                         hasce  taracq texamas  tari  tariq  anvan_erkarutun
# 0  Համբարձումյան Փ.   14   33      28   22/22  1997     27                5
# 1        Իսակովի Փ.   99   15      28    5/08  1964     60                6

# %%
df.isna() # None
# Out:
#          azganun   anun  haeranun  or_amis_tari   marz  hamaenq  bnakavaer  \
# 0          False  False     False         False  False    False       True
# 1          False  False     False         False  False    False       True
# 2          False  False     False         False  False    False       True
# 3          False  False     False         False  False    False       True
# 4          False  False     False         False  False    False       True
# ...          ...    ...       ...           ...    ...      ...        ...
# 2577168    False  False     False         False  False    False       True
# 2577169    False  False     False         False  False    False       True
# 2577170    False  False     False         False  False    False       True
# 2577171    False  False     False         False  False    False       True
# 2577172    False  False     False         False  False    False       True
#
#          hasce  taracq  texamas   tari  tariq  anvan_erkarutun
# 0        False   False    False  False  False            False
# 1        False   False    False  False  False            False
# 2        False   False    False  False  False            False
# 3        False   False    False  False  False            False
# 4        False   False    False  False  False            False
# ...        ...     ...      ...    ...    ...              ...
# 2577168  False   False    False  False  False            False
# 2577169  False   False    False  False  False            False
# 2577170  False   False    False  False  False            False
# 2577171  False   False    False  False  False            False
# 2577172  False   False    False  False  False            False
#
# [2577173 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# azganun                  0
# anun                     0
# haeranun               278
# or_amis_tari             0
# marz                    24
# hamaenq                 24
# bnakavaer          2042152
# hasce                  745
# taracq                   0
# texamas                  0
# tari                     0
# tariq                    0
# anvan_erkarutun          0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 2043223

# %%
df[df.hasce.isna()]
# Out:
#                azganun      anun    haeranun or_amis_tari    marz  \
# 7637         Դամիրչյան   Գուրգեն   Համազասպի   08/10/1966  ԿՈՏԱՅՔ
# 9280          Միրզոյան      Վահե     Վազգենի   19/08/2002  ԿՈՏԱՅՔ
# 11346        Գրիգորյան  Ջուլիետա     Յուրիկի   01/05/1958  ԿՈՏԱՅՔ
# 16718         Վանեսյան    Արմինե     Ռուբենի   22/10/1984  ԿՈՏԱՅՔ
# 18047          Չոլոյան     Նավաթ  Հովհաննեսի   05/03/1953  ԿՈՏԱՅՔ
# ...                ...       ...         ...          ...     ...
# 2556378         Պալյան    Մարինե      Կամոյի   01/12/1966    ԼՈՌԻ
# 2557777  Հարությունյան    Անահիտ     Հմայակի   23/02/2003    ԼՈՌԻ
# 2560216     Կոստանդյան    Լամարա     Մկրտիչի   19/02/1992    ԼՈՌԻ
# 2565522      Սարդարյան      Նառա     Արթուրի   10/12/1996    ԼՈՌԻ
# 2574709        Մադոյան    Ստյոպա      Վասիլի   13/08/1934    ԼՈՌԻ
#
#                   hamaenq    bnakavaer hasce  taracq texamas  tari  tariq  \
# 7637              ԴԻԼԻՋԱՆ          NaN   NaN      28   25/39  1966     58
# 9280              ՈՍԿԵՀԱՏ  ԲՅՈՒՐԵՂԱՎԱՆ   NaN      28   10/27  2002     22
# 11346                 ԱՆԻ  ԲՅՈՒՐԵՂԱՎԱՆ   NaN      28   31/11  1958     66
# 16718            ՇԵՆԳԱՎԻԹ  ԲՅՈՒՐԵՂԱՎԱՆ   NaN      28   23/41  1984     40
# 18047            ՍԱՍՈՒՆԻԿ       ԱԿՈՒՆՔ   NaN      28   31/22  1953     71
# ...                   ...          ...   ...     ...     ...   ...    ...
# 2556378             ԹԱԼԻՆ          NaN   NaN      23   38/15  1966     58
# 2557777          ՎԱՐԴԱՁՈՐ          NaN   NaN      23    7/57  2003     21
# 2560216  ՆԵՐՔԻՆ ԲԱԶՄԱԲԵՐԴ          NaN   NaN      23   35/55  1992     32
# 2565522        ՎԱՂԱՐՇԱՊԱՏ          NaN   NaN      23   29/29  1996     28
# 2574709           ԱՐՏԱՇԱՏ          NaN   NaN      23    3/01  1934     90
#
#          anvan_erkarutun
# 7637                   7
# 9280                   4
# 11346                  8
# 16718                  6
# 18047                  5
# ...                  ...
# 2556378                6
# 2557777                6
# 2560216                6
# 2565522                4
# 2574709                6
#
# [745 rows x 13 columns]

# %%
df.hasce.dropna() #.isna().sum()
# Out:
# 0          Համբարձումյան Փ.   14   33
# 1                Իսակովի Փ.   99   15
# 2                  Չեխովի Փ.   34   3
# 3                Գուսան Աշոտի Փ.   11
# 4                Պռոշյան Փ.   10   27
#                       ...
# 2577168        Շահումյան Փ.   97   46
# 2577169        Բ. Մարտիրոսյան Փ.   23
# 2577170          Թումանյան 3 Նրբ.   8
# 2577171                      9 Փ.   1
# 2577172       Վիլնյուսի Փ.   115   40
# Name: hasce, Length: 2577173, dtype: object

# %%
df.fillna('ոչմիբան', inplace=True)

# %%
df
# Out:
#                azganun        anun    haeranun or_amis_tari    marz  \
# 0        Հարությունյան       Կարեն     Գրիգորի   14/11/1997  ԿՈՏԱՅՔ
# 1            Աղաջանյան      Կարինե    Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ
# 2        Հարությունյան  Հարություն       Աշոտի   29/10/1986  ԿՈՏԱՅՔ
# 3           Ալեքսանյան      Համեստ      Շամիրի   24/10/1954  ԿՈՏԱՅՔ
# 4        Հարությունյան       Շաքար       Արամի   01/01/1959  ԿՈՏԱՅՔ
# ...                ...         ...         ...          ...     ...
# 2577168     Շահվերդյան         Ալա     Սեդրակի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան      Կարինե  Անուշավանի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան      Անահիտ      Լեւոնի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան      Նարինե     Ռուբենի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան      Գայանե       Էդիկի   24/04/1966    ԼՈՌԻ
#
#            hamaenq bnakavaer                       hasce  taracq texamas  \
# 0         ՇԵՆԳԱՎԻԹ   ոչմիբան  Համբարձումյան Փ.   14   33      28   22/22
# 1          ԱՐՏԻՄԵՏ   ոչմիբան        Իսակովի Փ.   99   15      28    5/08
# 2           ԻՋԵՎԱՆ   ոչմիբան          Չեխովի Փ.   34   3      28   14/03
# 3          ՌԱՆՉՊԱՐ   ոչմիբան        Գուսան Աշոտի Փ.   11      28   32/38
# 4          ԱԲՈՎՅԱՆ   ոչմիբան        Պռոշյան Փ.   10   27      28   13/15
# ...            ...       ...                         ...     ...     ...
# 2577168     ՍԻՍԻԱՆ   ոչմիբան      Շահումյան Փ.   97   46      23   18/69
# 2577169  ՇԱՀՈՒՄՅԱՆ   ոչմիբան      Բ. Մարտիրոսյան Փ.   23      23   13/54
# 2577170     ՍԻՍԻԱՆ   ոչմիբան        Թումանյան 3 Նրբ.   8      23    6/39
# 2577171   ՇԵՆԳԱՎԻԹ   ոչմիբան                    9 Փ.   1      23   33/11
# 2577172       ՎԵԴԻ   ոչմիբան     Վիլնյուսի Փ.   115   40      23   32/23
#
#          tari  tariq  anvan_erkarutun
# 0        1997     27                5
# 1        1964     60                6
# 2        1986     38               10
# 3        1954     70                6
# 4        1959     65                5
# ...       ...    ...              ...
# 2577168  1987     37                3
# 2577169  1960     64                6
# 2577170  1970     54                6
# 2577171  1978     46                6
# 2577172  1966     58                6
#
# [2577173 rows x 13 columns]

# %% [markdown]
# ## Վերանվանում, փոխարինում

# %%
df.rename(columns={'anun':'Անուն', 'azganun': 'Ազգանուն'})
# Out:
#               Ազգանուն       Անուն    haeranun or_amis_tari    marz  \
# 0        Հարությունյան       Կարեն     Գրիգորի   14/11/1997  ԿՈՏԱՅՔ
# 1            Աղաջանյան      Կարինե    Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ
# 2        Հարությունյան  Հարություն       Աշոտի   29/10/1986  ԿՈՏԱՅՔ
# 3           Ալեքսանյան      Համեստ      Շամիրի   24/10/1954  ԿՈՏԱՅՔ
# 4        Հարությունյան       Շաքար       Արամի   01/01/1959  ԿՈՏԱՅՔ
# ...                ...         ...         ...          ...     ...
# 2577168     Շահվերդյան         Ալա     Սեդրակի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան      Կարինե  Անուշավանի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան      Անահիտ      Լեւոնի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան      Նարինե     Ռուբենի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան      Գայանե       Էդիկի   24/04/1966    ԼՈՌԻ
#
#            hamaenq bnakavaer                       hasce  taracq texamas  \
# 0         ՇԵՆԳԱՎԻԹ   ոչմիբան  Համբարձումյան Փ.   14   33      28   22/22
# 1          ԱՐՏԻՄԵՏ   ոչմիբան        Իսակովի Փ.   99   15      28    5/08
# 2           ԻՋԵՎԱՆ   ոչմիբան          Չեխովի Փ.   34   3      28   14/03
# 3          ՌԱՆՉՊԱՐ   ոչմիբան        Գուսան Աշոտի Փ.   11      28   32/38
# 4          ԱԲՈՎՅԱՆ   ոչմիբան        Պռոշյան Փ.   10   27      28   13/15
# ...            ...       ...                         ...     ...     ...
# 2577168     ՍԻՍԻԱՆ   ոչմիբան      Շահումյան Փ.   97   46      23   18/69
# 2577169  ՇԱՀՈՒՄՅԱՆ   ոչմիբան      Բ. Մարտիրոսյան Փ.   23      23   13/54
# 2577170     ՍԻՍԻԱՆ   ոչմիբան        Թումանյան 3 Նրբ.   8      23    6/39
# 2577171   ՇԵՆԳԱՎԻԹ   ոչմիբան                    9 Փ.   1      23   33/11
# 2577172       ՎԵԴԻ   ոչմիբան     Վիլնյուսի Փ.   115   40      23   32/23
#
#          tari  tariq  anvan_erkarutun
# 0        1997     27                5
# 1        1964     60                6
# 2        1986     38               10
# 3        1954     70                6
# 4        1959     65                5
# ...       ...    ...              ...
# 2577168  1987     37                3
# 2577169  1960     64                6
# 2577170  1970     54                6
# 2577171  1978     46                6
# 2577172  1966     58                6
#
# [2577173 rows x 13 columns]

# %%
df.rename(index={1: 'մեկ', 3:'երեք'})
# Out:
#                azganun        anun    haeranun or_amis_tari    marz  \
# 0        Հարությունյան       Կարեն     Գրիգորի   14/11/1997  ԿՈՏԱՅՔ
# մեկ          Աղաջանյան      Կարինե    Մամիկոնի   14/08/1964  ԿՈՏԱՅՔ
# 2        Հարությունյան  Հարություն       Աշոտի   29/10/1986  ԿՈՏԱՅՔ
# երեք        Ալեքսանյան      Համեստ      Շամիրի   24/10/1954  ԿՈՏԱՅՔ
# 4        Հարությունյան       Շաքար       Արամի   01/01/1959  ԿՈՏԱՅՔ
# ...                ...         ...         ...          ...     ...
# 2577168     Շահվերդյան         Ալա     Սեդրակի   22/04/1987    ԼՈՌԻ
# 2577169      Իսրաելյան      Կարինե  Անուշավանի   13/03/1960    ԼՈՌԻ
# 2577170      Գրիգորյան      Անահիտ      Լեւոնի   12/05/1970    ԼՈՌԻ
# 2577171       Սահակյան      Նարինե     Ռուբենի   25/09/1978    ԼՈՌԻ
# 2577172       Մկրտչյան      Գայանե       Էդիկի   24/04/1966    ԼՈՌԻ
#
#            hamaenq bnakavaer                       hasce  taracq texamas  \
# 0         ՇԵՆԳԱՎԻԹ   ոչմիբան  Համբարձումյան Փ.   14   33      28   22/22
# մեկ        ԱՐՏԻՄԵՏ   ոչմիբան        Իսակովի Փ.   99   15      28    5/08
# 2           ԻՋԵՎԱՆ   ոչմիբան          Չեխովի Փ.   34   3      28   14/03
# երեք       ՌԱՆՉՊԱՐ   ոչմիբան        Գուսան Աշոտի Փ.   11      28   32/38
# 4          ԱԲՈՎՅԱՆ   ոչմիբան        Պռոշյան Փ.   10   27      28   13/15
# ...            ...       ...                         ...     ...     ...
# 2577168     ՍԻՍԻԱՆ   ոչմիբան      Շահումյան Փ.   97   46      23   18/69
# 2577169  ՇԱՀՈՒՄՅԱՆ   ոչմիբան      Բ. Մարտիրոսյան Փ.   23      23   13/54
# 2577170     ՍԻՍԻԱՆ   ոչմիբան        Թումանյան 3 Նրբ.   8      23    6/39
# 2577171   ՇԵՆԳԱՎԻԹ   ոչմիբան                    9 Փ.   1      23   33/11
# 2577172       ՎԵԴԻ   ոչմիբան     Վիլնյուսի Փ.   115   40      23   32/23
#
#          tari  tariq  anvan_erkarutun
# 0        1997     27                5
# մեկ      1964     60                6
# 2        1986     38               10
# երեք     1954     70                6
# 4        1959     65                5
# ...       ...    ...              ...
# 2577168  1987     37                3
# 2577169  1960     64                6
# 2577170  1970     54                6
# 2577171  1978     46                6
# 2577172  1966     58                6
#
# [2577173 rows x 13 columns]

# %%
df.replace({'ԿՈՏԱՅՔ': 'Կ', "ԼՈՌԻ": "Լ"})
# Out:
#                azganun        anun    haeranun or_amis_tari marz    hamaenq  \
# 0        Հարությունյան       Կարեն     Գրիգորի   14/11/1997    Կ   ՇԵՆԳԱՎԻԹ
# 1            Աղաջանյան      Կարինե    Մամիկոնի   14/08/1964    Կ    ԱՐՏԻՄԵՏ
# 2        Հարությունյան  Հարություն       Աշոտի   29/10/1986    Կ     ԻՋԵՎԱՆ
# 3           Ալեքսանյան      Համեստ      Շամիրի   24/10/1954    Կ    ՌԱՆՉՊԱՐ
# 4        Հարությունյան       Շաքար       Արամի   01/01/1959    Կ    ԱԲՈՎՅԱՆ
# ...                ...         ...         ...          ...  ...        ...
# 2577168     Շահվերդյան         Ալա     Սեդրակի   22/04/1987    Լ     ՍԻՍԻԱՆ
# 2577169      Իսրաելյան      Կարինե  Անուշավանի   13/03/1960    Լ  ՇԱՀՈՒՄՅԱՆ
# 2577170      Գրիգորյան      Անահիտ      Լեւոնի   12/05/1970    Լ     ՍԻՍԻԱՆ
# 2577171       Սահակյան      Նարինե     Ռուբենի   25/09/1978    Լ   ՇԵՆԳԱՎԻԹ
# 2577172       Մկրտչյան      Գայանե       Էդիկի   24/04/1966    Լ       ՎԵԴԻ
#
#         bnakavaer                       hasce  taracq texamas  tari  tariq  \
# 0         ոչմիբան  Համբարձումյան Փ.   14   33      28   22/22  1997     27
# 1         ոչմիբան        Իսակովի Փ.   99   15      28    5/08  1964     60
# 2         ոչմիբան          Չեխովի Փ.   34   3      28   14/03  1986     38
# 3         ոչմիբան        Գուսան Աշոտի Փ.   11      28   32/38  1954     70
# 4         ոչմիբան        Պռոշյան Փ.   10   27      28   13/15  1959     65
# ...           ...                         ...     ...     ...   ...    ...
# 2577168   ոչմիբան      Շահումյան Փ.   97   46      23   18/69  1987     37
# 2577169   ոչմիբան      Բ. Մարտիրոսյան Փ.   23      23   13/54  1960     64
# 2577170   ոչմիբան        Թումանյան 3 Նրբ.   8      23    6/39  1970     54
# 2577171   ոչմիբան                    9 Փ.   1      23   33/11  1978     46
# 2577172   ոչմիբան     Վիլնյուսի Փ.   115   40      23   32/23  1966     58
#
#          anvan_erkarutun
# 0                      5
# 1                      6
# 2                     10
# 3                      6
# 4                      5
# ...                  ...
# 2577168                3
# 2577169                6
# 2577170                6
# 2577171                6
# 2577172                6
#
# [2577173 rows x 13 columns]

# %% [markdown]
# ## Save անել

# %%
# %%time
old_df.to_csv("data.csv", index=False)
# Out:
# CPU times: user 18.3 s, sys: 908 ms, total: 19.2 s
# Wall time: 19.4 s

# %% [markdown]
# ### parquet file
# գուցե պետք լինի pyarrow install անել

# %%
# %%time
old_df.to_parquet("data.parquet", index=False)
# Out:
# CPU times: user 5.05 s, sys: 1.09 s, total: 6.14 s
# Wall time: 6.41 s

# %%
# %%time
new_df = pd.read_csv("data.csv")
# Out:
# CPU times: user 9.89 s, sys: 2.02 s, total: 11.9 s
# Wall time: 12.1 s

# %%
# %%time
new_df = pd.read_parquet("data.parquet")
# Out:
# CPU times: user 3.1 s, sys: 904 ms, total: 4 s
# Wall time: 3.89 s

# %%
import os

file1 = 'data.csv'
file2 = 'data.parquet'

file1_size = os.path.getsize(file1)
file2_size = os.path.getsize(file2)

# Print file sizes
print(f"Size of {file1}: {file1_size // 1024 // 1024} megabytes")
print(f"Size of {file2}: {file2_size // 1024 // 1024} megabytes")
print(file1_size / file2_size)
# Out:
# Size of data.csv: 367 megabytes
# Size of data.parquet: 63 megabytes
# 5.757054217552085

# %% [markdown]
# # 🏡Տնային
# Վերցնել ցանկցած դատասեթ ու փորփրել։
#
# Կարող եք դատան վերցնել [Kaggle](https://www.kaggle.com/datasets?fileType=csv)-ից։ Կամ եթե հայկական եք ուզում՝ [Armstat](https://armstat.am/am/)-ից

# %% [markdown]
# # 🎲 21 (03)
# - ▶️[Գիտադարան](https://www.youtube.com/watch?v=Y0Vu7_YDH3g)
# - ▶️[Video 🔥](https://www.youtube.com/shorts/UW37dEq-G5w)
# - 🇦🇲🎶[Կոմիտաս](https://www.youtube.com/watch?v=nHK7b0v7fYU)
# - 🌐🎶[Punch Brothers](https://www.youtube.com/watch?v=1ooqsxtdGS0)
# - 🤌[Կարգին](https://www.youtube.com/watch?v=5h70tn0asdo)

# %% [markdown]
# <a href="http://s01.flagcounter.com/more/1oO"><img src="https://s01.flagcounter.com/count2/1oO/bg_FFFFFF/txt_000000/border_CCCCCC/columns_2/maxflags_10/viewers_0/labels_0/pageviews_1/flags_0/percent_0/" alt="Flag Counter"></a>
