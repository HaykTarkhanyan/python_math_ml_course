# %% [raw]
# ---
# title: "09 Testing + Debugging"
# lightbox: true
# format:
#   html:
#     code-fold: false
# number-offset: 1
# ---

# %% [markdown]
# ![image.png](../background_photos/libs_09_dsegh.jpg)
# Դսեղ, [լուսանկարի հղումը](https://github.com/HaykTarkhanyan/python_math_ml_course/blob/main/background_photos/libs_09_dsegh.jpg), Հեղինակ՝ Ռոզի

# %% [markdown]
# <a href="ToDo" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> (ToDo)

# %% [markdown]
# > If debugging is the process of removing bugs. Then programming must be the process of putting them in.
#
# Edsger Dijkstra

# %% [markdown]
# # 📌 Նկարագիր (ToDo)
#
# [📚 Ամբողջական նյութը](09_testing__debugging.ipynb)
#
# ### 📺 Տեսանյութեր

# %% [markdown]
# # 📚 Նյութը
#
# - Unittest գրադարանը 2023 թվականի [վիդեոում](https://youtu.be/H6UN4S1Fbds?list=PLfLD2TpGxVUwUa_o8Fxig8SlC1PrLYWUg&t=2923)
#
# **Pytest**
#
# **Դասի կոդերը**
#
# - [Folder-ի հղումը](https://github.com/HaykTarkhanyan/python_math_ml_course/tree/main/python_libs/testing)
# - [calculator.py](testing/calculator.py)
# - [test_calculator.py](testing/test_calculator.py)
# - [elections.py](testing/elections.py)
# - [test_elections.py](testing/test_elections.py)
#
# - [Լավ վիդեո (33 րոպե)](https://www.youtube.com/watch?v=EgpLj86ZHFQ)
# - [Documentation](https://docs.pytest.org/)
#
# `uv pip install pytest`
# Configure VS Code
#
# 1. Simple tests
# 2. Unit tests idea
# 3. Parameterized tests
# 4. Fixtures (setup)
# 5. Fixtures (teardown)
# 6. Mocking
# 7. Coverage

# %% [markdown]
# ## Debugging
# [Լավ 7 րոպեանոց վիդեո](https://www.youtube.com/watch?v=XmpIBsnc3xU)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 🎲 27 (09)
# - ▶️[Historically](https://www.youtube.com/watch?v=FFxf_IsYm4Y)
# - 🔗[Random link](https://www.youtube.com/watch?v=1ws33f6qys4)
# - 🇦🇲🎶[Ladaniva](https://www.youtube.com/watch?v=UBlEicakwiY)
# - 🌐🎶[Sammy Copley](https://www.youtube.com/watch?v=exbu88zb6TU)
# - 🤌[Կարգին](https://www.youtube.com/watch?v=28WMu33SaYY)

# %% [markdown]
# <a href="http://s01.flagcounter.com/more/1oO"><img src="https://s01.flagcounter.com/count2/1oO/bg_FFFFFF/txt_000000/border_CCCCCC/columns_2/maxflags_10/viewers_0/labels_0/pageviews_1/flags_0/percent_0/" alt="Flag Counter"></a>
